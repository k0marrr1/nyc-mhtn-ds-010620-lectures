# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('world-happiness-report-2005-2018.csv', sep=';')

# %%
df.head(30)
# Out:
#    Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 0   Afghanistan  2008     3.723590            7.168690        0.450662
# 1   Afghanistan  2009     4.401778            7.333790        0.552308
# 2   Afghanistan  2010     4.758381            7.386629        0.539075
# 3   Afghanistan  2011     3.831719            7.415019        0.521104
# 4   Afghanistan  2012     3.782938            7.517126        0.520637
# 5   Afghanistan  2013     3.572100            7.522238        0.483552
# 6   Afghanistan  2014     3.130896            7.516955        0.525568
# 7   Afghanistan  2015     3.982855            7.500539        0.528597
# 8   Afghanistan  2016     4.220169            7.497038        0.559072
# 9   Afghanistan  2017     2.661718            7.497755        0.490880
# 10  Afghanistan  2018     2.694303            7.494588        0.507516
# 11      Albania  2007     4.634252            9.077331        0.821372
# ...

# %%
df.isnull().mean()
# Out:
# Country name                                                0.000000
# Year                                                        0.000000
# Life Ladder                                                 0.000000
# Log GDP per capita                                          0.016432
# Social support                                              0.007629
# Healthy life expectancy at birth                            0.016432
# Freedom to make life choices                                0.017019
# Generosity                                                  0.048122
# Perceptions of corruption                                   0.056338
# Positive affect                                             0.011150
# Negative affect                                             0.007629
# Confidence in national government                           0.102113
# Democratic Quality                                          0.085681
# Delivery Quality                                            0.085094
# ...

# %%
df = df[df['Year'] <= 2016]

# %%
Most = [var for var in df if 'Most' in var]
Most
# Out:
# ['Most people can be trusted, Gallup',
#  'Most people can be trusted, WVS round 1981-1984',
#  'Most people can be trusted, WVS round 1989-1993',
#  'Most people can be trusted, WVS round 1994-1998',
#  'Most people can be trusted, WVS round 1999-2004',
#  'Most people can be trusted, WVS round 2005-2009',
#  'Most people can be trusted, WVS round 2010-2014']

# %%
df = df.drop(Most, axis=1)

# %%
Gini = [var for var in df if 'GINI' in var]
Gini
# Out:
# ['GINI index (World Bank estimate)',
#  'GINI index (World Bank estimate), average 2000-16']

# %%
df = df.drop(Gini, axis=1)

# %%
gini = [var for var in df if 'gini' in var]
gini
# Out:
# ['gini of household income reported in Gallup, by wp5-year']

# %%
df = df.drop(gini, axis=1)

# %%
df.columns
# Out:
# Index(['Country name', 'Year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect',
#        'Confidence in national government', 'Democratic Quality',
#        'Delivery Quality', 'Standard deviation of ladder by country-year',
#        'Standard deviation/Mean of ladder by country-year'],
#       dtype='object')

# %%
df = df.rename(columns = {'Life Ladder':'Happy_index'})

# %%
df
# Out:
#      Country name  Year  Happy_index  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.168690        0.450662
# 1     Afghanistan  2009     4.401778            7.333790        0.552308
# 2     Afghanistan  2010     4.758381            7.386629        0.539075
# 3     Afghanistan  2011     3.831719            7.415019        0.521104
# 4     Afghanistan  2012     3.782938            7.517126        0.520637
# ...           ...   ...          ...                 ...             ...
# 1697     Zimbabwe  2012     4.955101            7.534424        0.896476
# 1698     Zimbabwe  2013     4.690188            7.565154        0.799274
# 1699     Zimbabwe  2014     4.184451            7.562753        0.765839
# 1700     Zimbabwe  2015     3.703191            7.556052        0.735800
# 1701     Zimbabwe  2016     3.735400            7.538829        0.768425
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
df1 = pd.read_csv('IHME-GBD_2017_DATA-f57da2bf-1.csv')

# %%
df1 = df1.rename(columns = {'location_name':'Country name'})

# %%
df1 = df1.sort_values(by = ['Country name', 'year'])

# %%
df1 = df1.drop('measure_id', axis=1)
df1 = df1.drop('sex_id', axis=1)
df1 = df1.drop('age_id', axis=1)
df1 = df1.drop('metric_id', axis=1)

# %%
df1
# Out:
#      measure_name  location_id Country name sex_name  age_name  cause_id  \
# 517        Deaths          160  Afghanistan     Both  All Ages       718
# 1139       Deaths          160  Afghanistan     Both  All Ages       718
# 1893       Deaths          160  Afghanistan     Both  All Ages       718
# 123        Deaths          160  Afghanistan     Both  All Ages       718
# 757        Deaths          160  Afghanistan     Both  All Ages       718
# ...           ...          ...          ...      ...       ...       ...
# 1002       Deaths          198     Zimbabwe     Both  All Ages       718
# 1526       Deaths          198     Zimbabwe     Both  All Ages       718
# 2272       Deaths          198     Zimbabwe     Both  All Ages       718
# 433        Deaths          198     Zimbabwe     Both  All Ages       718
# 1439       Deaths          198     Zimbabwe     Both  All Ages       718
#
#      cause_name metric_name  year        val      upper      lower
# ...

# %%
len(df)
# Out:
# 1421

# %%
len(df1)
# Out:
# 2340

# %%
df3 = pd.read_csv('UNdata_Export_20200222_205914330.csv')
df3.head(10)
# Out:
#   Country or Area  Year   Area         Sex      Age    Literacy  \
# 0         Albania  2011  Total  Both Sexes  10 - 14       Total
# 1         Albania  2011  Total  Both Sexes  10 - 14    Literate
# 2         Albania  2011  Total  Both Sexes  10 - 14  Illiterate
# 3         Albania  2011  Total  Both Sexes     10 +       Total
# 4         Albania  2011  Total  Both Sexes     10 +    Literate
# 5         Albania  2011  Total  Both Sexes     10 +  Illiterate
# 6         Albania  2011  Total  Both Sexes  15 - 19       Total
# 7         Albania  2011  Total  Both Sexes  15 - 19    Literate
# 8         Albania  2011  Total  Both Sexes  15 - 19  Illiterate
# 9         Albania  2011  Total  Both Sexes  20 - 24       Total
#
#                               Record Type             Reliability  \
# 0  Census - de jure - complete tabulation  Final figure, complete
# 1  Census - de jure - complete tabulation  Final figure, complete
# ...

# %%
#df3 = df3.dropna()

# %%
df3 = df3.drop('Area', axis=1)
df3 = df3.drop('Sex', axis=1)
df3 = df3.drop('Record Type', axis=1)
df3 = df3.drop('Reliability', axis=1)
df3 = df3.drop('Source Year', axis=1)
df3 = df3.drop('Value Footnotes', axis = 1)

# %%
df3.head(10)
# Out:
#   Country or Area  Year      Age    Literacy      Value
# 0         Albania  2011  10 - 14       Total   233376.0
# 1         Albania  2011  10 - 14    Literate   231653.0
# 2         Albania  2011  10 - 14  Illiterate     1723.0
# 3         Albania  2011     10 +       Total  2454948.0
# 4         Albania  2011     10 +    Literate  2387409.0
# 5         Albania  2011     10 +  Illiterate    67539.0
# 6         Albania  2011  15 - 19       Total   268746.0
# 7         Albania  2011  15 - 19    Literate   266391.0
# 8         Albania  2011  15 - 19  Illiterate     2355.0
# 9         Albania  2011  20 - 24       Total   243645.0

# %%
Total = df3.loc[(df3.Literacy == 'Total')&df3['Age'] == '10 +', ['Country or Area', 'Year', 'Value', 'Literacy']]

# %%
Lit = df3.loc[(df3.Literacy == 'Literate')&df3['Age'] == '10 +', ['Country or Area', 'Year', 'Value', 'Literacy']]

# %% [markdown]
# # Feature Selection
