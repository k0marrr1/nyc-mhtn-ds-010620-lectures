# %%
import requests
import json
client_id = 'DxQeJSiKJUmWIre2XGaKGg'
api_key = '37K09M8JaffyRQL_0ZZtHQCZxV_HsOlyXzY1wys6XhR6sJOJNf1H3ojayRAQnebOywHxZJOmZGxVvvAECfrX5uPgcunVHC8E6ThWcloYXHreayE6v3K2cbQYg_0pXnYx'

# %%
term = 'pub'
location = 'NY'
SEARCH_LIMIT = 50

url = 'https://api.yelp.com/v3/businesses/search'

headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

url_params = {
                    'term': term.replace(' ', '+'),
                    'location': location.replace(' ', '+'),
                    'limit': SEARCH_LIMIT
            }
response = requests.get(url, headers=headers, params=url_params)
data = response.json()
print(response)
print(type(response.text))
print(response.text)
# Out:
# <Response [200]>
# <class 'str'>
# {"businesses": [{"id": "oAjwUCzyvH9gBIOOlf8PtQ", "alias": "the-stinking-rose-pub-and-grindhouse-harcourt", "name": "The Stinking Rose Pub & Grindhouse", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/xsYj7Vzs5j_SHi994_9I7g/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-stinking-rose-pub-and-grindhouse-harcourt?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 1, "categories": [{"alias": "pubs", "title": "Pubs"}], "rating": 5.0, "coordinates": {"latitude": 44.30876, "longitude": -77.80071}, "transactions": [], "price": "$$", "location": {"address1": "26 Bridge West", "address2": "", "address3": "", "city": "Harcourt", "zip_code": "K0L", "country": "CA", "state": "ON", "display_address": ["26 Bridge West", "Harcourt, ON K0L", "Canada"]}, "phone": "+17056530001", "display_phone": "+1 705-653-0001", "distance": 810.2538134017361}, {"id": "OxqUWRZFUOz3r6_4bh4mfg", "alias": "cock-and-bull-new-york", "name": "Cock & Bull", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/-82MfQUN7FXel19Ra9BsLg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/cock-and-bull-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 531, "categories": [{"alias": "british", "title": "British"}, {"alias": "pubs", "title": "Pubs"}, {"alias": "gastropubs", "title": "Gastropubs"}], "rating": 4.0, "coordinates": {"latitude": 40.7560908823673, "longitude": -73.9804858350908}, "transactions": ["restaurant_reservation"], "price": "$$", "location": {"address1": "23 W 45th St", "address2": null, "address3": "", "city": "New York", "zip_code": "10036", "country": "US", "state": "NY", "display_address": ["23 W 45th St", "New York, NY 10036"]}, "phone": "+12128191900", "display_phone": "(212) 819-1900", "distance": 5750.495668005237}, {"id": "3NbhYebjZPjLTWZZyRuhsw", "alias": "the-winslow-new-york-2", "name": "The Winslow", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/KqK_JDisR25T9QQdVvgHNg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-winslow-new-york-2?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 527, "categories": [{"alias": "pubs", "title": "Pubs"}, {"alias": "british", "title": "British"}, {"alias": "cocktailbars", "title": "Cocktail Bars"}], "rating": 4.5, "coordinates": {"latitude": 40.7327766418457, "longitude": -73.9852142333984}, "transactions": ["restaurant_reservation"], "price": "$$", "location": {"address1": "243 E 14th St", "address2": "", "address3": "", "city": "New York", "zip_code": "10003", "country": "US", "state": "NY", "display_address": ["243 E 14th St", "New York, NY 10003"]}, "phone": "+12127777717", "display_phone": "(212) 777-7717", "distance": 3132.7023604652477}, {"id": "1pMep2AS_MPdobWwDzgkPw", "alias": "4th-avenue-pub-brooklyn", "name": "4th Avenue Pub", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/Gi7PJWArnJwk6wGV99WIhQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/4th-avenue-pub-brooklyn?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 306, "categories": [{"alias": "pubs", "title": "Pubs"}, {"alias": "beergardens", "title": "Beer Gardens"}, {"alias": "beerbar", "title": "Beer Bar"}], "rating": 4.0, "coordinates": {"latitude": 40.682325, "longitude": -73.980126}, "transactions": [], "price": "$$", "location": {"address1": "76 4th Ave", "address2": null, "address3": "", "city": "Brooklyn", "zip_code": "11217", "country": "US", "state": "NY", "display_address": ["76 4th Ave", "Brooklyn, NY 11217"]}, "phone": "+17186432273", "display_phone": "(718) 643-2273", "distance": 2839.66563564612}, {"id": "ZnhRUBos9FGQZrzbcPn6Vg", "alias": "o-haras-restaur ...

# %%
 def yelp_call():
    term = 'pub'
    location = 'NY'
    SEARCH_LIMIT = 50

    url = 'https://api.yelp.com/v3/businesses/search'

    headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

    url_params = {
                    'term': term.replace(' ', '+'),
                    'location': location.replace(' ', '+'),
                    'limit': SEARCH_LIMIT
            }
    response = requests.get(url, headers=headers, params=url_params)
    print(response)
    print(type(response.text))
    print(response.text)
    return response.json()

# %%
def create_database(cursor, database):
    try:
        cursor.execute(
            "CREATE DATABASE {} DEFAULT CHARACTER SET 'utf8'".format(database))
    except mysql.connector.Error as err:
        print("Failed creating database: {}".format(err))
        exit(1)

# %%
import mysql.connector
from mysql.connector import errorcode
cnx = mysql.connector.connect(
    host = 'database-1.cl7l8mgndgqj.us-east-2.rds.amazonaws.com',
    user = 'KuSin',
    passwd = 'Password',
    database = 'yelp'
)
cnx
cursor = cnx.cursor()
#user = "KuSin", passwd = "Password",

# %%
db_name = "yelp"
create_database(cursor, db_name)
# Out:
# Failed creating database: 1007 (HY000): Can't create database 'yelp'; database exists

# %%
TABLES = {}
TABLES['Businesses'] = (
    "CREATE TABLE Businesses ("
    "  id varchar(50),"
    "  name varchar(100),"
    "  price varchar(6),"
    "  rating float(6),"
    "  review_count int(10)"
    ") ENGINE=InnoDB")

# %%
for table_name in TABLES:
    table_description = TABLES[table_name]
    try:
        print("Creating table {}: ".format(table_name), end='')
        cursor.execute(table_description)
    except mysql.connector.Error as err:
        if err.errno == errorcode.ER_TABLE_EXISTS_ERROR:
            print("already exists.")
        else:
            print(err.msg)
    else:
        print("OK")
# Out:
# Creating table Businesses: OK

# %%
yelp_data = response.json()
yelp_data['businesses']
# Out:
# [{'id': 'oAjwUCzyvH9gBIOOlf8PtQ',
#   'alias': 'the-stinking-rose-pub-and-grindhouse-harcourt',
#   'name': 'The Stinking Rose Pub & Grindhouse',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xsYj7Vzs5j_SHi994_9I7g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-stinking-rose-pub-and-grindhouse-harcourt?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 1,
#   'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 44.30876, 'longitude': -77.80071},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '26 Bridge West',
#    'address2': '',
#    'address3': '',
#    'city': 'Harcourt',
#    'zip_code': 'K0L',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['26 Bridge West', 'Harcourt, ON K0L', 'Canada']},
#   'phone': '+17056530001',
#   'display_phone': '+1 705-653-0001',
#   'distance': 810.2538134017361},
#  {'id': 'OxqUWRZFUOz3r6_4bh4mfg',
#   'alias': 'cock-and-bull-new-york',
#   'name': 'Cock & Bull',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-82MfQUN7FXel19Ra9BsLg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/cock-and-bull-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 531,
#   'categories': [{'alias': 'british', 'title': 'British'},
#    {'alias': 'pubs', 'title': 'Pubs'},
#    {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7560908823673,
#    'longitude': -73.9804858350908},
#   'transactions': ['restaurant_reservation'],
#   'price': '$$',
#   'location': {'address1': '23 W 45th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10036',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['23 W 45th St', 'New York, NY 10036']},
#   'phone': '+12128191900',
#   'display_phone': '(212) 819-1900',
#   'distance': 5750.495668005237},
#  {'id': '3NbhYebjZPjLTWZZyRuhsw',
#   'alias': 'the-winslow-new-york-2',
#   'name': 'The Winslow',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KqK_JDisR25T9QQdVvgHNg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-winslow-new-york-2?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 527,
#   'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#    {'alias': 'british', 'title': 'British'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7327766418457,
#    'longitude': -73.9852142333984},
#   'transactions': ['restaurant_reservation'],
#   'price': '$$',
#   'location': {'address1': '243 E 14th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['243 E 14th St', 'New York, NY 10003']},
#   'phone': '+12127777717',
#   'display_phone': '(212) 777-7717',
#   'distance': 3132.7023604652477},
#  {'id': '1pMep2AS_MPdobWwDzgkPw',
#   'alias': '4th-avenue-pub-brooklyn',
#   'name': '4th Avenue Pub',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Gi7PJWArnJwk6wGV99WIhQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/4th-avenue-pub-brooklyn?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 306,
#   'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#    {'alias': 'beergardens', 'title': 'Beer Gardens'},
#    {'alias': 'beerbar', 'title': 'Beer Bar'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.682325, 'longitude': -73.980126},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '76 4th Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11217',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['76 4th Ave', 'Brooklyn, NY 11217']},
#   'phone': '+17186432273',
#   'display_phone': '(718) 643-2273',
#   'distance': 2839.66563564612},
#  {'id': 'ZnhRUBos9FGQZrzbcPn6Vg',
#   'alias': 'o-haras-restaurant-and-pub-new-york',
#   'name': "O'Hara's Restaurant and Pub",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nHPOfxtgtjaXPDWm6kPdIg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/o-haras-restaurant-and-pub-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 458,
#   'categories': [{'alias': 'irish_pubs', 'title': 'Irish Pub'},
#    {'alias': 'sportsbars', 'title': 'Sports Bars'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7093473589949,
#    'longitude': -74.0122557367896},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '120 Cedar St',
#    'address2': 'Ste 4',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10006',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['120 Cedar St', 'Ste 4', 'New York, NY 10006']},
#   'phone': '+12122673032',
#   'display_phone': '(212) 267-3032',
#   'distance': 1575.0396379671865},
#  {'id': 'bkIMbvXOcztDVz8bpyhMzQ',
#   'alias': 'the-dead-poet-new-york',
#   'name': 'The Dead Poet',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/fW9WcVHznuZMT-_x___jAg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-dead-poet-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 424,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.78499, 'longitude': -73.97735},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '450 Amsterdam Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10024',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['450 Amsterdam Ave', 'New York, NY 10024']},
#   'phone': '+12125955670',
#   'display_phone': '(212) 595-5670',
#   'distance': 8959.249622374835},
#  {'id': '7sQYI_Ym9RzlxHIhJpj6hg',
#   'alias': 'arts-and-crafts-beer-parlor-new-york',
#   'name': 'Arts and Crafts Beer Parlor',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XjByBmwSClE25ceHEGQKog/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/arts-and-crafts-beer-parlor-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 251,
#   'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#    {'alias': 'galleries', 'title': 'Art Galleries'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7327283010334,
#    'longitude': -73.9977158235951},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '26 W 8th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10011',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['26 W 8th St', 'New York, NY 10011']},
#   'phone': '+16466785263',
#   'display_phone': '(646) 678-5263',
#   'distance': 3047.4579245318782},
#  {'id': 'xHgMfdyLA5SPQz4c3ItTgg',
#   'alias': 'the-commissioner-brooklyn',
#   'name': 'The Commissioner',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Gc6HAJi7wmioqZG3NH7H5A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-commissioner-brooklyn?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 133,
#   'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.67487, 'longitude': -73.98137},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '247 5th Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11215',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['247 5th Ave', 'Brooklyn, NY 11215']},
#   'phone': '+13476893968',
#   'display_phone': '(347) 689-3968',
#   'distance': 3580.9767232086915},
#  {'id': 'K21NqbD_aa2FDUmQkKRltQ',
#   'alias': 'the-four-faced-liar-new-york',
#   'name': 'The Four-Faced Liar',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SoPqt1S8XRavNN44HVsGUw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-four-faced-liar-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 222,
#   'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7322235107422,
#    'longitude': -74.0013046264648},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '165 W 4th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['165 W 4th St', 'New York, NY 10014']},
#   'phone': '+12122068959',
#   'display_phone': '(212) 206-8959',
#   'distance': 3036.852474988448},
#  {'id': 'RemvTpxalDjSew5HwmNzUQ',
#   'alias': 'the-dead-rabbit-new-york',
#   'name': 'The Dead Rabbit',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_4T5R0HHhASROheby-TXDA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-dead-rabbit-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 1555,
#   'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.70329, 'longitude': -74.01102},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '30 Water St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10004',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['30 Water St', 'New York, NY 10004']},
#   'phone': '+16464227906',
#   'display_phone': '(646) 422-7906',
#   'distance': 1431.0399855447463},
#  {'id': 'QArou0r7CmLNPWYRA9ecog',
#   'alias': 'mcsorleys-old-ale-house-new-york',
#   'name': 'McSorleys Old Ale House',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rMVnbtW504_4qK93_9Fy9w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mcsorleys-old-ale-house-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 1757,
#   'categories': [{'alias': 'divebars', 'title': 'Dive Bars'},
#    {'alias': 'breweries', 'title': 'Breweries'},
#    {'alias': 'beerbar', 'title': 'Beer Bar'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.72884, 'longitude': -73.98965},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '15 E 7th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['15 E 7th St', 'New York, NY 10003']},
#   'phone': '+12124739148',
#   'display_phone': '(212) 473-9148',
#   'distance': 2627.521769759495},
#  {'id': 'ZCfqAtpASbibf_YaU1rIpw',
#   'alias': 'the-grafton-new-york',
#   'name': 'The Grafton',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/f75fH67vErRNzpa0N6Yr-A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-grafton-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 78,
#   'categories': [{'alias': 'irish', 'title': 'Irish'},
#    {'alias': 'pubs', 'title': 'Pubs'},
#    {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7271881103516,
#    'longitude': -73.9851989746094},
#   'transactions': ['pickup'],
#   'price': '$$',
#   'location': {'address1': '126 1st Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['126 1st Ave', 'New York, NY 10009']},
#   'phone': '+12122288580',
#   'display_phone': '(212) 228-8580',
#   'distance': 2537.8846268918337},
#  {'id': 'c3Ww3pgeHjBi3ctkeUWrjQ',
#   'alias': 'whiskey-tavern-new-york',
#   'name': 'Whiskey Tavern',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/P3eezkfdJ1cP3Z34T5Kmyg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/whiskey-tavern-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 780,
#   'categories': [{'alias': 'whiskeybars', 'title': 'Whiskey Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.71646, 'longitude': -73.99969},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '79 Baxter St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['79 Baxter St', 'New York, NY 10013']},
#   'phone': '+12123749119',
#   'display_phone': '(212) 374-9119',
#   'distance': 1309.1739793690049},
#  {'id': 'lHGQM__w1x5Dxiq3aRPCTQ',
#   'alias': 'white-horse-tavern-financial-district-new-york',
#   'name': 'White Horse Tavern - Financial District',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YV-yxNcjo9RzuTdNZnY4Ow/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/white-horse-tavern-financial-district-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 368,
#   'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.70372, 'longitude': -74.01237},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '25 Bridge St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10004',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['25 Bridge St', 'New York, NY 10004']},
#   'phone': '+12126689046',
#   'display_phone': '(212) 668-9046',
#   'distance': 1537.340275509881},
#  {'id': 'PMp7WlHIXQUnej-Ds1jRfw',
#   'alias': 'blind-tiger-ale-house-new-york',
#   'name': 'Blind Tiger Ale House',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/em6l-CtzWbuca3-Y9lRMsQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/blind-tiger-ale-house-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 882,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'pubs', 'title': 'Pubs'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.731926, 'longitude': -74.003223},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '281 Bleecker St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['281 Bleecker St', 'New York, NY 10014']},
#   'phone': '+12124624682',
#   'display_phone': '(212) 462-4682',
#   'distance': 3039.2154288142483},
#  {'id': '7boggcCID7gVdNFQn4e8hQ',
#   'alias': 'carraghers-pub-and-restaurant-new-york',
#   'name': "Carragher's Pub & Restaurant",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KaAommL_qMw09IV_AY3x0Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/carraghers-pub-and-restaurant-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 224,
#   'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#    {'alias': 'sportsbars', 'title': 'Sports Bars'},
#    {'alias': 'british', 'title': 'British'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7561483754108,
#    'longitude': -73.9908477827673},
#   'transactions': ['pickup'],
#   'price': '$$',
#   'location': {'address1': '228 W 39th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10018',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['228 W 39th St', 'New York, NY 10018']},
#   'phone': '+16463701545',
#   'display_phone': '(646) 370-1545',
#   'distance': 5645.436681619799},
#  {'id': 'vdrHSnRc1X2pJiLJuiOfGA',
#   'alias': 'toad-hall-new-york',
#   'name': 'Toad Hall',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QHfbz3p0vptHHUJ1ODe1Qg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/toad-hall-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 99,
#   'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#    {'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.722114, 'longitude': -74.003608},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '57 Grand St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['57 Grand St', 'New York, NY 10013']},
#   'phone': '+12124318145',
#   'display_phone': '(212) 431-8145',
#   'distance': 2014.5673798454595},
#  {'id': 'FgsN_18sk15FcTnYY3Ghjg',
#   'alias': 'the-irish-american-new-york-2',
#   'name': 'The Irish American',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fCC0O8bsYa7ztIVa2yY-hg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-irish-american-new-york-2?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 289,
#   'categories': [{'alias': 'irish_pubs', 'title': 'Irish Pub'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.71015, 'longitude': -74.008781},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '17 John St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10038',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['17 John St', 'New York, NY 10038']},
#   'phone': '+16464146223',
#   'display_phone': '(646) 414-6223',
#   'distance': 1328.5404928833252},
#  {'id': 'kMxXLrASxsbmS-ZzAaBe-A',
#   'alias': 'mollys-new-york',
#   'name': "Molly's",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/pIec8HcSiNhaj8DOORL9Cg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mollys-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 504,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'irish', 'title': 'Irish'},
#    {'alias': 'irish_pubs', 'title': 'Irish Pub'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.73825, 'longitude': -73.98321},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '287 3rd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10010',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['287 3rd Ave', 'New York, NY 10010']},
#   'phone': '+12128893361',
#   'display_phone': '(212) 889-3361',
#   'distance': 3764.352123073312},
#  {'id': 'zjoHov9SWVHHUk_2zSNzPA',
#   'alias': 'o-donnells-pub-harrison-2',
#   'name': "O'Donnell's Pub",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RhoJ8BUIaOYj_YZUyMBMZA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/o-donnells-pub-harrison-2?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 15,
#   'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.74585, 'longitude': -74.15875},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '233 Harrison Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Harrison',
#    'zip_code': '07029',
#    'country': 'US',
#    'state': 'NJ',
#    'display_address': ['233 Harrison Ave', 'Harrison, NJ 07029']},
#   'phone': '+19734829800',
#   'display_phone': '(973) 482-9800',
#   'distance': 14574.180719247894},
#  {'id': 'dzlhiEg7nE49iReUC10w_A',
#   'alias': 'jack-the-horse-tavern-brooklyn',
#   'name': 'Jack the Horse Tavern',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cGMc4G5EoTZFjMzrvX_lFw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/jack-the-horse-tavern-brooklyn?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 387,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.699973, 'longitude': -73.993781},
#   'transactions': ['restaurant_reservation'],
#   'price': '$$$',
#   'location': {'address1': '66 Hicks St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['66 Hicks St', 'Brooklyn, NY 11201']},
#   'phone': '+17188525084',
#   'display_phone': '(718) 852-5084',
#   'distance': 602.6367999119216},
#  {'id': '3ESlPTtjsEsyI5jhJFvBbw',
#   'alias': 'the-porterhouse-brewing-company-new-york',
#   'name': 'The Porterhouse Brewing Company',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hFxNAl6S8hStrPXOCU9G-w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-porterhouse-brewing-company-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 118,
#   'categories': [{'alias': 'breweries', 'title': 'Breweries'},
#    {'alias': 'pubs', 'title': 'Pubs'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7032627, 'longitude': -74.0107867},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '36 Water St',
#    'address2': '',
#    'address3': '58 Pearl St',
#    'city': 'New York',
#    'zip_code': '10004',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['36 Water St', '58 Pearl St', 'New York, NY 10004']},
#   'phone': '+12124257171',
#   'display_phone': '(212) 425-7171',
#   'distance': 1405.968175059443},
#  {'id': '1hScmfYV42XshcprL79MAQ',
#   'alias': 'peter-dillons-new-york',
#   'name': "Peter Dillon's",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Z_n0NX7ncxVi_hEBW_NqhQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/peter-dillons-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 204,
#   'categories': [{'alias': 'irish_pubs', 'title': 'Irish Pub'},
#    {'alias': 'beerbar', 'title': 'Beer Bar'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.749947565026, 'longitude': -73.976572493217},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '130 E 40th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10016',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['130 E 40th St', 'New York, NY 10016']},
#   'phone': '+12122133998',
#   'display_phone': '(212) 213-3998',
#   'distance': 5168.861479849484},
#  {'id': 'IGZkGbwE36iE1yaDW5NNKA',
#   'alias': 'the-flying-cock-new-york-2',
#   'name': 'The Flying Cock',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/j4Dj-ygooVetcKpW8RrxQQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-flying-cock-new-york-2?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 533,
#   'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.745296, 'longitude': -73.978073},
#   'transactions': ['restaurant_reservation'],
#   'price': '$$',
#   'location': {'address1': '497 3rd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10016',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['497 3rd Ave', 'New York, NY 10016']},
#   'phone': '+12126896900',
#   'display_phone': '(212) 689-6900',
#   'distance': 4636.094189982053},
#  {'id': 'H3AnaDvXg_tXticwUGL7PA',
#   'alias': 'hudson-hound-new-york',
#   'name': 'Hudson Hound',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HO2K2U7Sqrw9pz9JXFIvfw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hudson-hound-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 104,
#   'categories': [{'alias': 'irish_pubs', 'title': 'Irish Pub'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.73615, 'longitude': -74.00609},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '575 Hudson St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['575 Hudson St', 'New York, NY 10014']},
#   'phone': '+12127966213',
#   'display_phone': '(212) 796-6213',
#   'distance': 3555.6152052036864},
#  {'id': 's-n0KW8iqiq-C96tpxm2rA',
#   'alias': 'the-hairy-lemon-pub-new-york',
#   'name': 'The Hairy Lemon Pub',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/aRmKntAuTiKO34lZeaAvhg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-hairy-lemon-pub-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 65,
#   'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'irish_pubs', 'title': 'Irish Pub'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.72249, 'longitude': -73.98338},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '28 Avenue B',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['28 Avenue B', 'New York, NY 10009']},
#   'phone': '+16468692151',
#   'display_phone': '(646) 869-2151',
#   'distance': 2105.520027011804},
#  {'id': 'J4-UKUUx_cuclPt__ZwOPg',
#   'alias': 'one-mile-house-new-york',
#   'name': 'One Mile House',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zN4cRIs6R8aV_gM32hypVQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/one-mile-house-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 241,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.720394, 'longitude': -73.99321},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '10 Delancey St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['10 Delancey St', 'New York, NY 10002']},
#   'phone': '+16465590702',
#   'display_phone': '(646) 559-0702',
#   'distance': 1661.5125284281778},
#  {'id': 'lqkqsHe_2KN35LE5JIaYNg',
#   'alias': 'henry-street-ale-house-brooklyn',
#   'name': 'Henry Street Ale House',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5cD7ylAXMHvQpy8r9sjhvw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/henry-street-ale-house-brooklyn?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 223,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'beerbar', 'title': 'Beer Bar'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.6991054, 'longitude': -73.9923515},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '62 Henry St',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['62 Henry St', 'Brooklyn, NY 11201']},
#   'phone': '+17185224801',
#   'display_phone': '(718) 522-4801',
#   'distance': 723.6695736116728},
#  {'id': 'mVN2G1c5bRtAsNlr2Tbx6Q',
#   'alias': 'white-oak-tavern-new-york-2',
#   'name': 'White Oak Tavern',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/W_dXK7KSfJpWVKgPG6iuZw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/white-oak-tavern-new-york-2?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 347,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'whiskeybars', 'title': 'Whiskey Bars'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.730379, 'longitude': -73.99462},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '21 Waverly Pl',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['21 Waverly Pl', 'New York, NY 10003']},
#   'phone': '+12122602604',
#   'display_phone': '(212) 260-2604',
#   'distance': 2772.6830836631348},
#  {'id': 'veku2cg2qaV-7MxwhOMBmg',
#   'alias': 'judge-roy-bean-public-house-new-york',
#   'name': 'Judge Roy Bean Public House',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Ylc5xPFBBIH0bVNqDQV9LQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/judge-roy-bean-public-house-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 737,
#   'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#    {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7629158108786,
#    'longitude': -73.9761248066812},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '38 W 56th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10019',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['38 W 56th St', 'New York, NY 10019']},
#   'phone': '+12122628300',
#   'display_phone': '(212) 262-8300',
#   'distance': 6571.265299457194},
#  {'id': 'VNee09tB2NVGTe3g1tFylw',
#   'alias': 'petes-tavern-new-york',
#   'name': "Pete's Tavern",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ouaE4nHXON7dNabRZcuVoA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/petes-tavern-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 610,
#   'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.73647, 'longitude': -73.986698},
#   'transactions': ['restaurant_reservation'],
#   'price': '$$',
#   'location': {'address1': '129 E 18th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['129 E 18th St', 'New York, NY 10003']},
#   'phone': '+12124737676',
#   'display_phone': '(212) 473-7676',
#   'distance': 3508.711345298866},
#  {'id': 'SBLoGGk936tFHg0gYSZ-ow',
#   'alias': 'kent-ale-house-brooklyn',
#   'name': 'Kent Ale House',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/if-xMQCIGEVmXBSbUJIvXA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kent-ale-house-brooklyn?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 162,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'pubs', 'title': 'Pubs'},
#    {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7223281860352,
#    'longitude': -73.9592514038086},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '51 Kent Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11249',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['51 Kent Ave', 'Brooklyn, NY 11249']},
#   'phone': '+13472278624',
#   'display_phone': '(347) 227-8624',
#   'distance': 3497.2903432486546},
#  {'id': 'IBgjj5VBu5JJvKgo9EzKrg',
#   'alias': 'the-three-monkeys-new-york-3',
#   'name': 'The Three Monkeys',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/9PvL7hV_rZUQI0AiAaGSwA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-three-monkeys-new-york-3?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 1142,
#   'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#    {'alias': 'beergardens', 'title': 'Beer Gardens'},
#    {'alias': 'beerbar', 'title': 'Beer Bar'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.764164, 'longitude': -73.98306},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '236 W 54th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10019',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['236 W 54th St', 'New York, NY 10019']},
#   'phone': '+12125862080',
#   'display_phone': '(212) 586-2080',
#   'distance': 6597.505592442847},
#  {'id': 'Gey_giAxXSzPbpVigXV9jQ',
#   'alias': 'paddy-maguires-ale-house-new-york',
#   'name': "Paddy Maguire's Ale House",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wKFhzMgK7IkuD_L4j_1Bsw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/paddy-maguires-ale-house-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 81,
#   'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#    {'alias': 'irish_pubs', 'title': 'Irish Pub'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7364240384139,
#    'longitude': -73.9848463081818},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '237 3rd Ave Frnt',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['237 3rd Ave Frnt', 'New York, NY 10003']},
#   'phone': '+12122530031',
#   'display_phone': '(212) 253-0031',
#   'distance': 3535.5253603734595},
#  {'id': 'yFB5JUiz-SPpnhWg2iCU9w',
#   'alias': 'the-long-hall-pub-and-grocery-new-york',
#   'name': 'The Long Hall Pub & Grocery',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/--cwK5KlAWGecZfa2k-Q3g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-long-hall-pub-and-grocery-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 103,
#   'categories': [{'alias': 'irish_pubs', 'title': 'Irish Pub'},
#    {'alias': 'grocery', 'title': 'Grocery'},
#    {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7472791, 'longitude': -73.9821609},
#   'transactions': ['pickup'],
#   'price': '$$',
#   'location': {'address1': '58 E 34th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10016',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['58 E 34th St', 'New York, NY 10016']},
#   'phone': '+16464550777',
#   'display_phone': '(646) 455-0777',
#   'distance': 4762.770903928266},
#  {'id': 'GW42yOQB6G97Pc0KujI3lA',
#   'alias': 'donovans-pub-woodside',
#   'name': "Donovan's Pub",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/evQLTnNRluU4N_zRL5FmWQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/donovans-pub-woodside?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 416,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'pubs', 'title': 'Pubs'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7452467497759,
#    'longitude': -73.9068230114332},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '57-24 Roosevelt Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Woodside',
#    'zip_code': '11377',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['57-24 Roosevelt Ave', 'Woodside, NY 11377']},
#   'phone': '+17184299339',
#   'display_phone': '(718) 429-9339',
#   'distance': 8597.602493312226},
#  {'id': 'NPG2jp4C61RJbmbA35p6xA',
#   'alias': 'john-sullivans-new-york',
#   'name': "John Sullivan's",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/zRVLcpjebW5npVWXcGOUQQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/john-sullivans-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 214,
#   'categories': [{'alias': 'irish', 'title': 'Irish'},
#    {'alias': 'irish_pubs', 'title': 'Irish Pub'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7517735073233,
#    'longitude': -73.9905076101422},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '210 W 35th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10001',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['210 W 35th St', 'New York, NY 10001']},
#   'phone': '+12129937223',
#   'display_phone': '(212) 993-7223',
#   'distance': 5161.371177678675},
#  {'id': 'f7i6LxdwbDXExDn_58tXaA',
#   'alias': 'the-ginger-man-new-york',
#   'name': 'The Ginger Man',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5fy7M13PYofC0WQ-kKdJRQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-ginger-man-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 1352,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'breweries', 'title': 'Breweries'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.749459, 'longitude': -73.982743},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '11 E 36th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10016',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['11 E 36th St', 'New York, NY 10016']},
#   'phone': '+12125323740',
#   'display_phone': '(212) 532-3740',
#   'distance': 4989.98270936944},
#  {'id': 'pC92jJr2d1VrxGKRNPPERA',
#   'alias': '11th-street-bar-new-york',
#   'name': '11th Street Bar',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qLVsJ46LDgnfxOFl3X1Ujw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/11th-street-bar-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 136,
#   'categories': [{'alias': 'irish_pubs', 'title': 'Irish Pub'},
#    {'alias': 'musicvenues', 'title': 'Music Venues'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.72802, 'longitude': -73.98128},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '510 E 11th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['510 E 11th St', 'New York, NY 10009']},
#   'phone': '+12129823929',
#   'display_phone': '(212) 982-3929',
#   'distance': 2737.470139363503},
#  {'id': 'rvabT9eHrKFKgfNPrp69Zw',
#   'alias': 'the-waylon-new-york',
#   'name': 'The Waylon',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KnIlR3e8Va5TYl7a-gcXjQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-waylon-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 112,
#   'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7650840967709,
#    'longitude': -73.9918056894333},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '736 10th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10019',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['736 10th Ave', 'New York, NY 10019']},
#   'phone': '+12122650010',
#   'display_phone': '(212) 265-0010',
#   'distance': 6634.883870962165},
#  {'id': 'LDwxXfapMw6xNbTF0YDFaQ',
#   'alias': 'brooklyn-public-house-brooklyn',
#   'name': 'Brooklyn Public House',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FDWK4uHA-a8xhmMDNzXJ-A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/brooklyn-public-house-brooklyn?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 317,
#   'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.68958, 'longitude': -73.96939},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '247 Dekalb Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11205',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['247 Dekalb Ave', 'Brooklyn, NY 11205']},
#   'phone': '+13472278976',
#   'display_phone': '(347) 227-8976',
#   'distance': 2738.4094534097794},
#  {'id': 'Xu8H24NxJJxEE-9wGp_AMA',
#   'alias': 'the-brazen-tavern-new-york',
#   'name': 'The Brazen Tavern',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nwiNdF2nps6Lvbu7EihGbA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-brazen-tavern-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 377,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7593269348145,
#    'longitude': -73.9913101196289},
#   'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '356 W 44th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10036',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['356 W 44th St', 'New York, NY 10036']},
#   'phone': '+16466785989',
#   'display_phone': '(646) 678-5989',
#   'distance': 5998.398762920218},
#  {'id': 'sDajjybHSYFw8gTVbknPGA',
#   'alias': 'jack-doyles-bar-and-restaurant-new-york',
#   'name': "Jack Doyle's Bar & Restaurant",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/46eVvthYVkODJrUiRQmE_A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/jack-doyles-bar-and-restaurant-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 324,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'pubs', 'title': 'Pubs'},
#    {'alias': 'irish', 'title': 'Irish'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.752132, 'longitude': -73.991852},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '240 W 35th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10001',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['240 W 35th St', 'New York, NY 10001']},
#   'phone': '+12122681255',
#   'display_phone': '(212) 268-1255',
#   'distance': 5195.561920241944},
#  {'id': 'uVimnyjMcc7MOGzd2NRX-w',
#   'alias': 'north-pole-pub-brooklyn',
#   'name': 'North Pole Pub',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dzqZcwY-Sv-89hxS2CYgAQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/north-pole-pub-brooklyn?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 39,
#   'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.68154, 'longitude': -73.9774},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '428 Bergen St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11217',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['428 Bergen St', 'Brooklyn, NY 11217']},
#   'phone': '+17188570049',
#   'display_phone': '(718) 857-0049',
#   'distance': 3018.6812276285787},
#  {'id': 'Z65cd3Z7JvwK8TnSVg-cfA',
#   'alias': 'district-tap-house-new-york',
#   'name': 'District Tap House',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HtzE4VgpvhDsAgoNxv7_Ww/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/district-tap-house-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 822,
#   'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#    {'alias': 'pubs', 'title': 'Pubs'},
#    {'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.75409, 'longitude': -73.99039},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '246 W 38th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10018',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['246 W 38th St', 'New York, NY 10018']},
#   'phone': '+12122211822',
#   'display_phone': '(212) 221-1822',
#   'distance': 5412.960609159312},
#  {'id': 'jJfCbhEnI5PMPW_vS-Pp6g',
#   'alias': 'black-rabbit-brooklyn',
#   'name': 'Black Rabbit',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/EXZmUJrPyokZJjHIJn1zQg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/black-rabbit-brooklyn?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 169,
#   'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7301408235242,
#    'longitude': -73.9563193070954},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '91 Greenpoint Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11222',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['91 Greenpoint Ave', 'Brooklyn, NY 11222']},
#   'phone': '+17183491595',
#   'display_phone': '(718) 349-1595',
#   'distance': 4217.014499488315},
#  {'id': '74FFOreAgPphSwSZlfZzgw',
#   'alias': 'jones-wood-foundry-new-york-2',
#   'name': 'Jones Wood Foundry',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/g_JO_38cTxVr0txyBxEumw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/jones-wood-foundry-new-york-2?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 631,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'gastropubs', 'title': 'Gastropubs'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7703854340118,
#    'longitude': -73.9535711917713},
#   'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '401 E 76th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10021',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['401 E 76th St', 'New York, NY 10021']},
#   'phone': '+12122492700',
#   'display_phone': '(212) 249-2700',
#   'distance': 7994.681771202271},
#  {'id': 'RBkz0yuQfs_5ExPhL-6jpg',
#   'alias': 'slainte-bar-and-lounge-new-york',
#   'name': 'Slainte Bar & Lounge',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cvI6vjPFy5ENIY3Zt5ZFKw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/slainte-bar-and-lounge-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 238,
#   'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#    {'alias': 'irish', 'title': 'Irish'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.724811, 'longitude': -73.992832},
#   'transactions': ['pickup'],
#   'price': '$$',
#   'location': {'address1': '304 Bowery',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['304 Bowery', 'New York, NY 10012']},
#   'phone': '+12122537030',
#   'display_phone': '(212) 253-7030',
#   'distance': 2156.9323064841687},
#  {'id': 'Co6-ZaY0sBNCC3I8L0PAFw',
#   'alias': 'graces-new-york',
#   'name': "Grace's",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/60F5MKSndCbQOhKPZmjuoA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/graces-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 29,
#   'categories': [{'alias': 'irish_pubs', 'title': 'Irish Pub'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.73936, 'longitude': -74.00223},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '252 West 14th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10011',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['252 West 14th St', 'New York, NY 10011']},
#   'phone': '+16468700333',
#   'display_phone': '(646) 870-0333',
#   'distance': 3834.742594760696},
#  {'id': '6hKJePanmG9AxK4dfwgyyg',
#   'alias': 'the-horny-ram-new-york-2',
#   'name': 'The Horny Ram',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/r7ChItmOrNARZf1IqqG1RQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-horny-ram-new-york-2?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg',
#   'review_count': 454,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#    {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.75528, 'longitude': -73.96857},
#   'transactions': ['restaurant_reservation'],
#   'price': '$$',
#   'location': {'address1': '951 2nd Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10022',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['951 2nd Ave', 'New York, NY 10022']},
#   'phone': '+19172614136',
#   'display_phone': '(917) 261-4136',
#   'distance': 5949.853020058706}]

# %%
def parsed_tuples(yelp_data):
    parsed_tuple_list = []
    for i in yelp_data['businesses']:
        if 'id' in i:
            pass
        else:
            i['id'] = 'nan'
        if 'name' in i:
            pass
        else:
            i['name']='nan'
        if 'review_count' in i:
            pass
        else:
            i['review_count']='nan'
        if 'rating' in i:
            pass
        else:
            i['rating']='nan'
        if 'price' in i:
            pass
        else:
            i['price']='nan'
        parsed_tuple_list.append((i['id'], i['name'], i['review_count'], i['rating'], i['price']))
    return parsed_tuple_list
aa=parsed_tuples(yelp_data)
aa
# Out:
# [('oAjwUCzyvH9gBIOOlf8PtQ',
#   'The Stinking Rose Pub & Grindhouse',
#   1,
#   5.0,
#   '$$'),
#  ('OxqUWRZFUOz3r6_4bh4mfg', 'Cock & Bull', 531, 4.0, '$$'),
#  ('3NbhYebjZPjLTWZZyRuhsw', 'The Winslow', 527, 4.5, '$$'),
#  ('1pMep2AS_MPdobWwDzgkPw', '4th Avenue Pub', 306, 4.0, '$$'),
#  ('ZnhRUBos9FGQZrzbcPn6Vg', "O'Hara's Restaurant and Pub", 458, 4.0, '$$'),
#  ('bkIMbvXOcztDVz8bpyhMzQ', 'The Dead Poet', 424, 4.0, '$$'),
#  ('7sQYI_Ym9RzlxHIhJpj6hg', 'Arts and Crafts Beer Parlor', 251, 4.5, '$$'),
#  ('xHgMfdyLA5SPQz4c3ItTgg', 'The Commissioner', 133, 5.0, '$'),
#  ('K21NqbD_aa2FDUmQkKRltQ', 'The Four-Faced Liar', 222, 4.0, '$'),
#  ('RemvTpxalDjSew5HwmNzUQ', 'The Dead Rabbit', 1555, 4.0, '$$'),
#  ('QArou0r7CmLNPWYRA9ecog', 'McSorleys Old Ale House', 1757, 4.0, '$'),
#  ('ZCfqAtpASbibf_YaU1rIpw', 'The Grafton', 78, 4.0, '$$'),
#  ('c3Ww3pgeHjBi3ctkeUWrjQ', 'Whiskey Tavern', 780, 4.5, '$$'),
#  ('lHGQM__w1x5Dxiq3aRPCTQ',
#   'White Horse Tavern - Financial District',
#   368,
#   4.0,
#   '$'),
#  ('PMp7WlHIXQUnej-Ds1jRfw', 'Blind Tiger Ale House', 882, 4.0, '$$'),
#  ('7boggcCID7gVdNFQn4e8hQ', "Carragher's Pub & Restaurant", 224, 4.0, '$$'),
#  ('vdrHSnRc1X2pJiLJuiOfGA', 'Toad Hall', 99, 4.0, '$$'),
#  ('FgsN_18sk15FcTnYY3Ghjg', 'The Irish American', 289, 4.0, '$$'),
#  ('kMxXLrASxsbmS-ZzAaBe-A', "Molly's", 504, 4.0, '$$'),
#  ('zjoHov9SWVHHUk_2zSNzPA', "O'Donnell's Pub", 15, 5.0, '$$'),
#  ('dzlhiEg7nE49iReUC10w_A', 'Jack the Horse Tavern', 387, 4.0, '$$$'),
#  ('3ESlPTtjsEsyI5jhJFvBbw', 'The Porterhouse Brewing Company', 118, 4.0, '$$'),
#  ('1hScmfYV42XshcprL79MAQ', "Peter Dillon's", 204, 4.0, '$'),
#  ('IGZkGbwE36iE1yaDW5NNKA', 'The Flying Cock', 533, 4.0, '$$'),
#  ('H3AnaDvXg_tXticwUGL7PA', 'Hudson Hound', 104, 4.0, '$$'),
#  ('s-n0KW8iqiq-C96tpxm2rA', 'The Hairy Lemon Pub', 65, 4.5, '$'),
#  ('J4-UKUUx_cuclPt__ZwOPg', 'One Mile House', 241, 4.0, '$$'),
#  ('lqkqsHe_2KN35LE5JIaYNg', 'Henry Street Ale House', 223, 3.5, '$$'),
#  ('mVN2G1c5bRtAsNlr2Tbx6Q', 'White Oak Tavern', 347, 4.0, '$$'),
#  ('veku2cg2qaV-7MxwhOMBmg', 'Judge Roy Bean Public House', 737, 4.5, '$$'),
#  ('VNee09tB2NVGTe3g1tFylw', "Pete's Tavern", 610, 3.5, '$$'),
#  ('SBLoGGk936tFHg0gYSZ-ow', 'Kent Ale House', 162, 4.0, '$$'),
#  ('IBgjj5VBu5JJvKgo9EzKrg', 'The Three Monkeys', 1142, 4.0, '$$'),
#  ('Gey_giAxXSzPbpVigXV9jQ', "Paddy Maguire's Ale House", 81, 4.0, '$'),
#  ('yFB5JUiz-SPpnhWg2iCU9w', 'The Long Hall Pub & Grocery', 103, 4.5, '$$'),
#  ('GW42yOQB6G97Pc0KujI3lA', "Donovan's Pub", 416, 4.0, '$$'),
#  ('NPG2jp4C61RJbmbA35p6xA', "John Sullivan's", 214, 4.0, '$$'),
#  ('f7i6LxdwbDXExDn_58tXaA', 'The Ginger Man', 1352, 4.0, '$$'),
#  ('pC92jJr2d1VrxGKRNPPERA', '11th Street Bar', 136, 4.0, '$'),
#  ('rvabT9eHrKFKgfNPrp69Zw', 'The Waylon', 112, 4.5, '$$'),
#  ('LDwxXfapMw6xNbTF0YDFaQ', 'Brooklyn Public House', 317, 3.5, '$$'),
#  ('Xu8H24NxJJxEE-9wGp_AMA', 'The Brazen Tavern', 377, 4.5, '$$'),
#  ('sDajjybHSYFw8gTVbknPGA', "Jack Doyle's Bar & Restaurant", 324, 4.0, '$$'),
#  ('uVimnyjMcc7MOGzd2NRX-w', 'North Pole Pub', 39, 5.0, '$$'),
#  ('Z65cd3Z7JvwK8TnSVg-cfA', 'District Tap House', 822, 4.0, '$$'),
#  ('jJfCbhEnI5PMPW_vS-Pp6g', 'Black Rabbit', 169, 4.0, '$$'),
#  ('74FFOreAgPphSwSZlfZzgw', 'Jones Wood Foundry', 631, 4.0, '$$'),
#  ('RBkz0yuQfs_5ExPhL-6jpg', 'Slainte Bar & Lounge', 238, 4.0, '$$'),
#  ('Co6-ZaY0sBNCC3I8L0PAFw', "Grace's", 29, 4.5, '$$'),
#  ('6hKJePanmG9AxK4dfwgyyg', 'The Horny Ram', 454, 4.0, '$$')]

# %%
def db_insert(parsed_tuples):
    stmt = "INSERT INTO Businesses(id, name, review_count, rating, price) VALUES (%s, %s, %s, %s, %s)"
    cursor.executemany(stmt, aa)
    cnx.commit()

# %%
# create a variable  to keep track of which result you are in. 
cur = 0

#set up a while loop to go through and grab the result 
while cur < 1000:
    #set the offset parameter to be where you currently are in the results 
    url_params['offset'] = cur
    #make your API call with the new offset number
    results = yelp_call()
    
    #after you get your results you can now use your function to parse those results
    parsed_results = parsed_tuples(results)
    
    # use your function to insert your parsed results into the db
    db_insert(parsed_results)
    #increment the counter by 50 to move on to the next results
    cur += 50
# Out:
# <Response [200]>
# <class 'str'>
# {"businesses": [{"id": "oAjwUCzyvH9gBIOOlf8PtQ", "alias": "the-stinking-rose-pub-and-grindhouse-harcourt", "name": "The Stinking Rose Pub & Grindhouse", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/xsYj7Vzs5j_SHi994_9I7g/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-stinking-rose-pub-and-grindhouse-harcourt?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 1, "categories": [{"alias": "pubs", "title": "Pubs"}], "rating": 5.0, "coordinates": {"latitude": 44.30876, "longitude": -77.80071}, "transactions": [], "price": "$$", "location": {"address1": "26 Bridge West", "address2": "", "address3": "", "city": "Harcourt", "zip_code": "K0L", "country": "CA", "state": "ON", "display_address": ["26 Bridge West", "Harcourt, ON K0L", "Canada"]}, "phone": "+17056530001", "display_phone": "+1 705-653-0001", "distance": 810.2538134017361}, {"id": "OxqUWRZFUOz3r6_4bh4mfg", "alias": "cock-and-bull-new-york", "name": "Cock & Bull", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/-82MfQUN7FXel19Ra9BsLg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/cock-and-bull-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 531, "categories": [{"alias": "british", "title": "British"}, {"alias": "pubs", "title": "Pubs"}, {"alias": "gastropubs", "title": "Gastropubs"}], "rating": 4.0, "coordinates": {"latitude": 40.7560908823673, "longitude": -73.9804858350908}, "transactions": ["restaurant_reservation"], "price": "$$", "location": {"address1": "23 W 45th St", "address2": null, "address3": "", "city": "New York", "zip_code": "10036", "country": "US", "state": "NY", "display_address": ["23 W 45th St", "New York, NY 10036"]}, "phone": "+12128191900", "display_phone": "(212) 819-1900", "distance": 5750.495668005237}, {"id": "3NbhYebjZPjLTWZZyRuhsw", "alias": "the-winslow-new-york-2", "name": "The Winslow", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/KqK_JDisR25T9QQdVvgHNg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-winslow-new-york-2?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 527, "categories": [{"alias": "pubs", "title": "Pubs"}, {"alias": "british", "title": "British"}, {"alias": "cocktailbars", "title": "Cocktail Bars"}], "rating": 4.5, "coordinates": {"latitude": 40.7327766418457, "longitude": -73.9852142333984}, "transactions": ["restaurant_reservation"], "price": "$$", "location": {"address1": "243 E 14th St", "address2": "", "address3": "", "city": "New York", "zip_code": "10003", "country": "US", "state": "NY", "display_address": ["243 E 14th St", "New York, NY 10003"]}, "phone": "+12127777717", "display_phone": "(212) 777-7717", "distance": 3132.7023604652477}, {"id": "1pMep2AS_MPdobWwDzgkPw", "alias": "4th-avenue-pub-brooklyn", "name": "4th Avenue Pub", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/Gi7PJWArnJwk6wGV99WIhQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/4th-avenue-pub-brooklyn?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 306, "categories": [{"alias": "pubs", "title": "Pubs"}, {"alias": "beergardens", "title": "Beer Gardens"}, {"alias": "beerbar", "title": "Beer Bar"}], "rating": 4.0, "coordinates": {"latitude": 40.682325, "longitude": -73.980126}, "transactions": [], "price": "$$", "location": {"address1": "76 4th Ave", "address2": null, "address3": "", "city": "Brooklyn", "zip_code": "11217", "country": "US", "state": "NY", "display_address": ["76 4th Ave", "Brooklyn, NY 11217"]}, "phone": "+17186432273", "display_phone": "(718) 643-2273", "distance": 2839.66563564612}, {"id": "ZnhRUBos9FGQZrzbcPn6Vg", "alias": "o-haras-restaur ...
# <Response [200]>
# <class 'str'>
# {"businesses": [{"id": "oAjwUCzyvH9gBIOOlf8PtQ", "alias": "the-stinking-rose-pub-and-grindhouse-harcourt", "name": "The Stinking Rose Pub & Grindhouse", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/xsYj7Vzs5j_SHi994_9I7g/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-stinking-rose-pub-and-grindhouse-harcourt?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 1, "categories": [{"alias": "pubs", "title": "Pubs"}], "rating": 5.0, "coordinates": {"latitude": 44.30876, "longitude": -77.80071}, "transactions": [], "price": "$$", "location": {"address1": "26 Bridge West", "address2": "", "address3": "", "city": "Harcourt", "zip_code": "K0L", "country": "CA", "state": "ON", "display_address": ["26 Bridge West", "Harcourt, ON K0L", "Canada"]}, "phone": "+17056530001", "display_phone": "+1 705-653-0001", "distance": 810.2538134017361}, {"id": "OxqUWRZFUOz3r6_4bh4mfg", "alias": "cock-and-bull-new-york", "name": "Cock & Bull", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/-82MfQUN7FXel19Ra9BsLg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/cock-and-bull-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 531, "categories": [{"alias": "british", "title": "British"}, {"alias": "pubs", "title": "Pubs"}, {"alias": "gastropubs", "title": "Gastropubs"}], "rating": 4.0, "coordinates": {"latitude": 40.7560908823673, "longitude": -73.9804858350908}, "transactions": ["restaurant_reservation"], "price": "$$", "location": {"address1": "23 W 45th St", "address2": null, "address3": "", "city": "New York", "zip_code": "10036", "country": "US", "state": "NY", "display_address": ["23 W 45th St", "New York, NY 10036"]}, "phone": "+12128191900", "display_phone": "(212) 819-1900", "distance": 5750.495668005237}, {"id": "3NbhYebjZPjLTWZZyRuhsw", "alias": "the-winslow-new-york-2", "name": "The Winslow", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/KqK_JDisR25T9QQdVvgHNg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-winslow-new-york-2?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 527, "categories": [{"alias": "pubs", "title": "Pubs"}, {"alias": "british", "title": "British"}, {"alias": "cocktailbars", "title": "Cocktail Bars"}], "rating": 4.5, "coordinates": {"latitude": 40.7327766418457, "longitude": -73.9852142333984}, "transactions": ["restaurant_reservation"], "price": "$$", "location": {"address1": "243 E 14th St", "address2": "", "address3": "", "city": "New York", "zip_code": "10003", "country": "US", "state": "NY", "display_address": ["243 E 14th St", "New York, NY 10003"]}, "phone": "+12127777717", "display_phone": "(212) 777-7717", "distance": 3132.7023604652477}, {"id": "1pMep2AS_MPdobWwDzgkPw", "alias": "4th-avenue-pub-brooklyn", "name": "4th Avenue Pub", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/Gi7PJWArnJwk6wGV99WIhQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/4th-avenue-pub-brooklyn?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 306, "categories": [{"alias": "pubs", "title": "Pubs"}, {"alias": "beergardens", "title": "Beer Gardens"}, {"alias": "beerbar", "title": "Beer Bar"}], "rating": 4.0, "coordinates": {"latitude": 40.682325, "longitude": -73.980126}, "transactions": [], "price": "$$", "location": {"address1": "76 4th Ave", "address2": null, "address3": "", "city": "Brooklyn", "zip_code": "11217", "country": "US", "state": "NY", "display_address": ["76 4th Ave", "Brooklyn, NY 11217"]}, "phone": "+17186432273", "display_phone": "(718) 643-2273", "distance": 2839.66563564612}, {"id": "ZnhRUBos9FGQZrzbcPn6Vg", "alias": "o-haras-restaur ...
# <Response [200]>
# <class 'str'>
# {"businesses": [{"id": "oAjwUCzyvH9gBIOOlf8PtQ", "alias": "the-stinking-rose-pub-and-grindhouse-harcourt", "name": "The Stinking Rose Pub & Grindhouse", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/xsYj7Vzs5j_SHi994_9I7g/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-stinking-rose-pub-and-grindhouse-harcourt?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 1, "categories": [{"alias": "pubs", "title": "Pubs"}], "rating": 5.0, "coordinates": {"latitude": 44.30876, "longitude": -77.80071}, "transactions": [], "price": "$$", "location": {"address1": "26 Bridge West", "address2": "", "address3": "", "city": "Harcourt", "zip_code": "K0L", "country": "CA", "state": "ON", "display_address": ["26 Bridge West", "Harcourt, ON K0L", "Canada"]}, "phone": "+17056530001", "display_phone": "+1 705-653-0001", "distance": 810.2538134017361}, {"id": "OxqUWRZFUOz3r6_4bh4mfg", "alias": "cock-and-bull-new-york", "name": "Cock & Bull", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/-82MfQUN7FXel19Ra9BsLg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/cock-and-bull-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 531, "categories": [{"alias": "british", "title": "British"}, {"alias": "pubs", "title": "Pubs"}, {"alias": "gastropubs", "title": "Gastropubs"}], "rating": 4.0, "coordinates": {"latitude": 40.7560908823673, "longitude": -73.9804858350908}, "transactions": ["restaurant_reservation"], "price": "$$", "location": {"address1": "23 W 45th St", "address2": null, "address3": "", "city": "New York", "zip_code": "10036", "country": "US", "state": "NY", "display_address": ["23 W 45th St", "New York, NY 10036"]}, "phone": "+12128191900", "display_phone": "(212) 819-1900", "distance": 5750.495668005237}, {"id": "3NbhYebjZPjLTWZZyRuhsw", "alias": "the-winslow-new-york-2", "name": "The Winslow", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/KqK_JDisR25T9QQdVvgHNg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-winslow-new-york-2?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 527, "categories": [{"alias": "pubs", "title": "Pubs"}, {"alias": "british", "title": "British"}, {"alias": "cocktailbars", "title": "Cocktail Bars"}], "rating": 4.5, "coordinates": {"latitude": 40.7327766418457, "longitude": -73.9852142333984}, "transactions": ["restaurant_reservation"], "price": "$$", "location": {"address1": "243 E 14th St", "address2": "", "address3": "", "city": "New York", "zip_code": "10003", "country": "US", "state": "NY", "display_address": ["243 E 14th St", "New York, NY 10003"]}, "phone": "+12127777717", "display_phone": "(212) 777-7717", "distance": 3132.7023604652477}, {"id": "1pMep2AS_MPdobWwDzgkPw", "alias": "4th-avenue-pub-brooklyn", "name": "4th Avenue Pub", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/Gi7PJWArnJwk6wGV99WIhQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/4th-avenue-pub-brooklyn?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 306, "categories": [{"alias": "pubs", "title": "Pubs"}, {"alias": "beergardens", "title": "Beer Gardens"}, {"alias": "beerbar", "title": "Beer Bar"}], "rating": 4.0, "coordinates": {"latitude": 40.682325, "longitude": -73.980126}, "transactions": [], "price": "$$", "location": {"address1": "76 4th Ave", "address2": null, "address3": "", "city": "Brooklyn", "zip_code": "11217", "country": "US", "state": "NY", "display_address": ["76 4th Ave", "Brooklyn, NY 11217"]}, "phone": "+17186432273", "display_phone": "(718) 643-2273", "distance": 2839.66563564612}, {"id": "ZnhRUBos9FGQZrzbcPn6Vg", "alias": "o-haras-restaur ...
# <Response [200]>
# <class 'str'>
# {"businesses": [{"id": "oAjwUCzyvH9gBIOOlf8PtQ", "alias": "the-stinking-rose-pub-and-grindhouse-harcourt", "name": "The Stinking Rose Pub & Grindhouse", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/xsYj7Vzs5j_SHi994_9I7g/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-stinking-rose-pub-and-grindhouse-harcourt?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 1, "categories": [{"alias": "pubs", "title": "Pubs"}], "rating": 5.0, "coordinates": {"latitude": 44.30876, "longitude": -77.80071}, "transactions": [], "price": "$$", "location": {"address1": "26 Bridge West", "address2": "", "address3": "", "city": "Harcourt", "zip_code": "K0L", "country": "CA", "state": "ON", "display_address": ["26 Bridge West", "Harcourt, ON K0L", "Canada"]}, "phone": "+17056530001", "display_phone": "+1 705-653-0001", "distance": 810.2538134017361}, {"id": "OxqUWRZFUOz3r6_4bh4mfg", "alias": "cock-and-bull-new-york", "name": "Cock & Bull", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/-82MfQUN7FXel19Ra9BsLg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/cock-and-bull-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 531, "categories": [{"alias": "british", "title": "British"}, {"alias": "pubs", "title": "Pubs"}, {"alias": "gastropubs", "title": "Gastropubs"}], "rating": 4.0, "coordinates": {"latitude": 40.7560908823673, "longitude": -73.9804858350908}, "transactions": ["restaurant_reservation"], "price": "$$", "location": {"address1": "23 W 45th St", "address2": null, "address3": "", "city": "New York", "zip_code": "10036", "country": "US", "state": "NY", "display_address": ["23 W 45th St", "New York, NY 10036"]}, "phone": "+12128191900", "display_phone": "(212) 819-1900", "distance": 5750.495668005237}, {"id": "3NbhYebjZPjLTWZZyRuhsw", "alias": "the-winslow-new-york-2", "name": "The Winslow", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/KqK_JDisR25T9QQdVvgHNg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-winslow-new-york-2?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 527, "categories": [{"alias": "pubs", "title": "Pubs"}, {"alias": "british", "title": "British"}, {"alias": "cocktailbars", "title": "Cocktail Bars"}], "rating": 4.5, "coordinates": {"latitude": 40.7327766418457, "longitude": -73.9852142333984}, "transactions": ["restaurant_reservation"], "price": "$$", "location": {"address1": "243 E 14th St", "address2": "", "address3": "", "city": "New York", "zip_code": "10003", "country": "US", "state": "NY", "display_address": ["243 E 14th St", "New York, NY 10003"]}, "phone": "+12127777717", "display_phone": "(212) 777-7717", "distance": 3132.7023604652477}, {"id": "1pMep2AS_MPdobWwDzgkPw", "alias": "4th-avenue-pub-brooklyn", "name": "4th Avenue Pub", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/Gi7PJWArnJwk6wGV99WIhQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/4th-avenue-pub-brooklyn?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 306, "categories": [{"alias": "pubs", "title": "Pubs"}, {"alias": "beergardens", "title": "Beer Gardens"}, {"alias": "beerbar", "title": "Beer Bar"}], "rating": 4.0, "coordinates": {"latitude": 40.682325, "longitude": -73.980126}, "transactions": [], "price": "$$", "location": {"address1": "76 4th Ave", "address2": null, "address3": "", "city": "Brooklyn", "zip_code": "11217", "country": "US", "state": "NY", "display_address": ["76 4th Ave", "Brooklyn, NY 11217"]}, "phone": "+17186432273", "display_phone": "(718) 643-2273", "distance": 2839.66563564612}, {"id": "ZnhRUBos9FGQZrzbcPn6Vg", "alias": "o-haras-restaur ...
# <Response [200]>
# <class 'str'>
# {"businesses": [{"id": "oAjwUCzyvH9gBIOOlf8PtQ", "alias": "the-stinking-rose-pub-and-grindhouse-harcourt", "name": "The Stinking Rose Pub & Grindhouse", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/xsYj7Vzs5j_SHi994_9I7g/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-stinking-rose-pub-and-grindhouse-harcourt?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 1, "categories": [{"alias": "pubs", "title": "Pubs"}], "rating": 5.0, "coordinates": {"latitude": 44.30876, "longitude": -77.80071}, "transactions": [], "price": "$$", "location": {"address1": "26 Bridge West", "address2": "", "address3": "", "city": "Harcourt", "zip_code": "K0L", "country": "CA", "state": "ON", "display_address": ["26 Bridge West", "Harcourt, ON K0L", "Canada"]}, "phone": "+17056530001", "display_phone": "+1 705-653-0001", "distance": 810.2538134017361}, {"id": "OxqUWRZFUOz3r6_4bh4mfg", "alias": "cock-and-bull-new-york", "name": "Cock & Bull", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/-82MfQUN7FXel19Ra9BsLg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/cock-and-bull-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 531, "categories": [{"alias": "british", "title": "British"}, {"alias": "pubs", "title": "Pubs"}, {"alias": "gastropubs", "title": "Gastropubs"}], "rating": 4.0, "coordinates": {"latitude": 40.7560908823673, "longitude": -73.9804858350908}, "transactions": ["restaurant_reservation"], "price": "$$", "location": {"address1": "23 W 45th St", "address2": null, "address3": "", "city": "New York", "zip_code": "10036", "country": "US", "state": "NY", "display_address": ["23 W 45th St", "New York, NY 10036"]}, "phone": "+12128191900", "display_phone": "(212) 819-1900", "distance": 5750.495668005237}, {"id": "3NbhYebjZPjLTWZZyRuhsw", "alias": "the-winslow-new-york-2", "name": "The Winslow", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/KqK_JDisR25T9QQdVvgHNg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-winslow-new-york-2?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 527, "categories": [{"alias": "pubs", "title": "Pubs"}, {"alias": "british", "title": "British"}, {"alias": "cocktailbars", "title": "Cocktail Bars"}], "rating": 4.5, "coordinates": {"latitude": 40.7327766418457, "longitude": -73.9852142333984}, "transactions": ["restaurant_reservation"], "price": "$$", "location": {"address1": "243 E 14th St", "address2": "", "address3": "", "city": "New York", "zip_code": "10003", "country": "US", "state": "NY", "display_address": ["243 E 14th St", "New York, NY 10003"]}, "phone": "+12127777717", "display_phone": "(212) 777-7717", "distance": 3132.7023604652477}, {"id": "1pMep2AS_MPdobWwDzgkPw", "alias": "4th-avenue-pub-brooklyn", "name": "4th Avenue Pub", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/Gi7PJWArnJwk6wGV99WIhQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/4th-avenue-pub-brooklyn?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 306, "categories": [{"alias": "pubs", "title": "Pubs"}, {"alias": "beergardens", "title": "Beer Gardens"}, {"alias": "beerbar", "title": "Beer Bar"}], "rating": 4.0, "coordinates": {"latitude": 40.682325, "longitude": -73.980126}, "transactions": [], "price": "$$", "location": {"address1": "76 4th Ave", "address2": null, "address3": "", "city": "Brooklyn", "zip_code": "11217", "country": "US", "state": "NY", "display_address": ["76 4th Ave", "Brooklyn, NY 11217"]}, "phone": "+17186432273", "display_phone": "(718) 643-2273", "distance": 2839.66563564612}, {"id": "ZnhRUBos9FGQZrzbcPn6Vg", "alias": "o-haras-restaur ...
# <Response [200]>
# <class 'str'>
# {"businesses": [{"id": "oAjwUCzyvH9gBIOOlf8PtQ", "alias": "the-stinking-rose-pub-and-grindhouse-harcourt", "name": "The Stinking Rose Pub & Grindhouse", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/xsYj7Vzs5j_SHi994_9I7g/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-stinking-rose-pub-and-grindhouse-harcourt?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 1, "categories": [{"alias": "pubs", "title": "Pubs"}], "rating": 5.0, "coordinates": {"latitude": 44.30876, "longitude": -77.80071}, "transactions": [], "price": "$$", "location": {"address1": "26 Bridge West", "address2": "", "address3": "", "city": "Harcourt", "zip_code": "K0L", "country": "CA", "state": "ON", "display_address": ["26 Bridge West", "Harcourt, ON K0L", "Canada"]}, "phone": "+17056530001", "display_phone": "+1 705-653-0001", "distance": 810.2538134017361}, {"id": "OxqUWRZFUOz3r6_4bh4mfg", "alias": "cock-and-bull-new-york", "name": "Cock & Bull", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/-82MfQUN7FXel19Ra9BsLg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/cock-and-bull-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 531, "categories": [{"alias": "british", "title": "British"}, {"alias": "pubs", "title": "Pubs"}, {"alias": "gastropubs", "title": "Gastropubs"}], "rating": 4.0, "coordinates": {"latitude": 40.7560908823673, "longitude": -73.9804858350908}, "transactions": ["restaurant_reservation"], "price": "$$", "location": {"address1": "23 W 45th St", "address2": null, "address3": "", "city": "New York", "zip_code": "10036", "country": "US", "state": "NY", "display_address": ["23 W 45th St", "New York, NY 10036"]}, "phone": "+12128191900", "display_phone": "(212) 819-1900", "distance": 5750.495668005237}, {"id": "3NbhYebjZPjLTWZZyRuhsw", "alias": "the-winslow-new-york-2", "name": "The Winslow", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/KqK_JDisR25T9QQdVvgHNg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-winslow-new-york-2?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 527, "categories": [{"alias": "pubs", "title": "Pubs"}, {"alias": "british", "title": "British"}, {"alias": "cocktailbars", "title": "Cocktail Bars"}], "rating": 4.5, "coordinates": {"latitude": 40.7327766418457, "longitude": -73.9852142333984}, "transactions": ["restaurant_reservation"], "price": "$$", "location": {"address1": "243 E 14th St", "address2": "", "address3": "", "city": "New York", "zip_code": "10003", "country": "US", "state": "NY", "display_address": ["243 E 14th St", "New York, NY 10003"]}, "phone": "+12127777717", "display_phone": "(212) 777-7717", "distance": 3132.7023604652477}, {"id": "1pMep2AS_MPdobWwDzgkPw", "alias": "4th-avenue-pub-brooklyn", "name": "4th Avenue Pub", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/Gi7PJWArnJwk6wGV99WIhQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/4th-avenue-pub-brooklyn?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 306, "categories": [{"alias": "pubs", "title": "Pubs"}, {"alias": "beergardens", "title": "Beer Gardens"}, {"alias": "beerbar", "title": "Beer Bar"}], "rating": 4.0, "coordinates": {"latitude": 40.682325, "longitude": -73.980126}, "transactions": [], "price": "$$", "location": {"address1": "76 4th Ave", "address2": null, "address3": "", "city": "Brooklyn", "zip_code": "11217", "country": "US", "state": "NY", "display_address": ["76 4th Ave", "Brooklyn, NY 11217"]}, "phone": "+17186432273", "display_phone": "(718) 643-2273", "distance": 2839.66563564612}, {"id": "ZnhRUBos9FGQZrzbcPn6Vg", "alias": "o-haras-restaur ...
# <Response [200]>
# <class 'str'>
# {"businesses": [{"id": "oAjwUCzyvH9gBIOOlf8PtQ", "alias": "the-stinking-rose-pub-and-grindhouse-harcourt", "name": "The Stinking Rose Pub & Grindhouse", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/xsYj7Vzs5j_SHi994_9I7g/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-stinking-rose-pub-and-grindhouse-harcourt?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 1, "categories": [{"alias": "pubs", "title": "Pubs"}], "rating": 5.0, "coordinates": {"latitude": 44.30876, "longitude": -77.80071}, "transactions": [], "price": "$$", "location": {"address1": "26 Bridge West", "address2": "", "address3": "", "city": "Harcourt", "zip_code": "K0L", "country": "CA", "state": "ON", "display_address": ["26 Bridge West", "Harcourt, ON K0L", "Canada"]}, "phone": "+17056530001", "display_phone": "+1 705-653-0001", "distance": 810.2538134017361}, {"id": "OxqUWRZFUOz3r6_4bh4mfg", "alias": "cock-and-bull-new-york", "name": "Cock & Bull", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/-82MfQUN7FXel19Ra9BsLg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/cock-and-bull-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 531, "categories": [{"alias": "british", "title": "British"}, {"alias": "pubs", "title": "Pubs"}, {"alias": "gastropubs", "title": "Gastropubs"}], "rating": 4.0, "coordinates": {"latitude": 40.7560908823673, "longitude": -73.9804858350908}, "transactions": ["restaurant_reservation"], "price": "$$", "location": {"address1": "23 W 45th St", "address2": null, "address3": "", "city": "New York", "zip_code": "10036", "country": "US", "state": "NY", "display_address": ["23 W 45th St", "New York, NY 10036"]}, "phone": "+12128191900", "display_phone": "(212) 819-1900", "distance": 5750.495668005237}, {"id": "3NbhYebjZPjLTWZZyRuhsw", "alias": "the-winslow-new-york-2", "name": "The Winslow", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/KqK_JDisR25T9QQdVvgHNg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-winslow-new-york-2?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 527, "categories": [{"alias": "pubs", "title": "Pubs"}, {"alias": "british", "title": "British"}, {"alias": "cocktailbars", "title": "Cocktail Bars"}], "rating": 4.5, "coordinates": {"latitude": 40.7327766418457, "longitude": -73.9852142333984}, "transactions": ["restaurant_reservation"], "price": "$$", "location": {"address1": "243 E 14th St", "address2": "", "address3": "", "city": "New York", "zip_code": "10003", "country": "US", "state": "NY", "display_address": ["243 E 14th St", "New York, NY 10003"]}, "phone": "+12127777717", "display_phone": "(212) 777-7717", "distance": 3132.7023604652477}, {"id": "1pMep2AS_MPdobWwDzgkPw", "alias": "4th-avenue-pub-brooklyn", "name": "4th Avenue Pub", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/Gi7PJWArnJwk6wGV99WIhQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/4th-avenue-pub-brooklyn?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 306, "categories": [{"alias": "pubs", "title": "Pubs"}, {"alias": "beergardens", "title": "Beer Gardens"}, {"alias": "beerbar", "title": "Beer Bar"}], "rating": 4.0, "coordinates": {"latitude": 40.682325, "longitude": -73.980126}, "transactions": [], "price": "$$", "location": {"address1": "76 4th Ave", "address2": null, "address3": "", "city": "Brooklyn", "zip_code": "11217", "country": "US", "state": "NY", "display_address": ["76 4th Ave", "Brooklyn, NY 11217"]}, "phone": "+17186432273", "display_phone": "(718) 643-2273", "distance": 2839.66563564612}, {"id": "ZnhRUBos9FGQZrzbcPn6Vg", "alias": "o-haras-restaur ...
# <Response [200]>
# <class 'str'>
# {"businesses": [{"id": "oAjwUCzyvH9gBIOOlf8PtQ", "alias": "the-stinking-rose-pub-and-grindhouse-harcourt", "name": "The Stinking Rose Pub & Grindhouse", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/xsYj7Vzs5j_SHi994_9I7g/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-stinking-rose-pub-and-grindhouse-harcourt?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 1, "categories": [{"alias": "pubs", "title": "Pubs"}], "rating": 5.0, "coordinates": {"latitude": 44.30876, "longitude": -77.80071}, "transactions": [], "price": "$$", "location": {"address1": "26 Bridge West", "address2": "", "address3": "", "city": "Harcourt", "zip_code": "K0L", "country": "CA", "state": "ON", "display_address": ["26 Bridge West", "Harcourt, ON K0L", "Canada"]}, "phone": "+17056530001", "display_phone": "+1 705-653-0001", "distance": 810.2538134017361}, {"id": "OxqUWRZFUOz3r6_4bh4mfg", "alias": "cock-and-bull-new-york", "name": "Cock & Bull", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/-82MfQUN7FXel19Ra9BsLg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/cock-and-bull-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 531, "categories": [{"alias": "british", "title": "British"}, {"alias": "pubs", "title": "Pubs"}, {"alias": "gastropubs", "title": "Gastropubs"}], "rating": 4.0, "coordinates": {"latitude": 40.7560908823673, "longitude": -73.9804858350908}, "transactions": ["restaurant_reservation"], "price": "$$", "location": {"address1": "23 W 45th St", "address2": null, "address3": "", "city": "New York", "zip_code": "10036", "country": "US", "state": "NY", "display_address": ["23 W 45th St", "New York, NY 10036"]}, "phone": "+12128191900", "display_phone": "(212) 819-1900", "distance": 5750.495668005237}, {"id": "3NbhYebjZPjLTWZZyRuhsw", "alias": "the-winslow-new-york-2", "name": "The Winslow", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/KqK_JDisR25T9QQdVvgHNg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-winslow-new-york-2?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 527, "categories": [{"alias": "pubs", "title": "Pubs"}, {"alias": "british", "title": "British"}, {"alias": "cocktailbars", "title": "Cocktail Bars"}], "rating": 4.5, "coordinates": {"latitude": 40.7327766418457, "longitude": -73.9852142333984}, "transactions": ["restaurant_reservation"], "price": "$$", "location": {"address1": "243 E 14th St", "address2": "", "address3": "", "city": "New York", "zip_code": "10003", "country": "US", "state": "NY", "display_address": ["243 E 14th St", "New York, NY 10003"]}, "phone": "+12127777717", "display_phone": "(212) 777-7717", "distance": 3132.7023604652477}, {"id": "1pMep2AS_MPdobWwDzgkPw", "alias": "4th-avenue-pub-brooklyn", "name": "4th Avenue Pub", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/Gi7PJWArnJwk6wGV99WIhQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/4th-avenue-pub-brooklyn?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 306, "categories": [{"alias": "pubs", "title": "Pubs"}, {"alias": "beergardens", "title": "Beer Gardens"}, {"alias": "beerbar", "title": "Beer Bar"}], "rating": 4.0, "coordinates": {"latitude": 40.682325, "longitude": -73.980126}, "transactions": [], "price": "$$", "location": {"address1": "76 4th Ave", "address2": null, "address3": "", "city": "Brooklyn", "zip_code": "11217", "country": "US", "state": "NY", "display_address": ["76 4th Ave", "Brooklyn, NY 11217"]}, "phone": "+17186432273", "display_phone": "(718) 643-2273", "distance": 2839.66563564612}, {"id": "ZnhRUBos9FGQZrzbcPn6Vg", "alias": "o-haras-restaur ...
# <Response [200]>
# <class 'str'>
# {"businesses": [{"id": "oAjwUCzyvH9gBIOOlf8PtQ", "alias": "the-stinking-rose-pub-and-grindhouse-harcourt", "name": "The Stinking Rose Pub & Grindhouse", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/xsYj7Vzs5j_SHi994_9I7g/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-stinking-rose-pub-and-grindhouse-harcourt?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 1, "categories": [{"alias": "pubs", "title": "Pubs"}], "rating": 5.0, "coordinates": {"latitude": 44.30876, "longitude": -77.80071}, "transactions": [], "price": "$$", "location": {"address1": "26 Bridge West", "address2": "", "address3": "", "city": "Harcourt", "zip_code": "K0L", "country": "CA", "state": "ON", "display_address": ["26 Bridge West", "Harcourt, ON K0L", "Canada"]}, "phone": "+17056530001", "display_phone": "+1 705-653-0001", "distance": 810.2538134017361}, {"id": "OxqUWRZFUOz3r6_4bh4mfg", "alias": "cock-and-bull-new-york", "name": "Cock & Bull", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/-82MfQUN7FXel19Ra9BsLg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/cock-and-bull-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 531, "categories": [{"alias": "british", "title": "British"}, {"alias": "pubs", "title": "Pubs"}, {"alias": "gastropubs", "title": "Gastropubs"}], "rating": 4.0, "coordinates": {"latitude": 40.7560908823673, "longitude": -73.9804858350908}, "transactions": ["restaurant_reservation"], "price": "$$", "location": {"address1": "23 W 45th St", "address2": null, "address3": "", "city": "New York", "zip_code": "10036", "country": "US", "state": "NY", "display_address": ["23 W 45th St", "New York, NY 10036"]}, "phone": "+12128191900", "display_phone": "(212) 819-1900", "distance": 5750.495668005237}, {"id": "3NbhYebjZPjLTWZZyRuhsw", "alias": "the-winslow-new-york-2", "name": "The Winslow", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/KqK_JDisR25T9QQdVvgHNg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-winslow-new-york-2?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 527, "categories": [{"alias": "pubs", "title": "Pubs"}, {"alias": "british", "title": "British"}, {"alias": "cocktailbars", "title": "Cocktail Bars"}], "rating": 4.5, "coordinates": {"latitude": 40.7327766418457, "longitude": -73.9852142333984}, "transactions": ["restaurant_reservation"], "price": "$$", "location": {"address1": "243 E 14th St", "address2": "", "address3": "", "city": "New York", "zip_code": "10003", "country": "US", "state": "NY", "display_address": ["243 E 14th St", "New York, NY 10003"]}, "phone": "+12127777717", "display_phone": "(212) 777-7717", "distance": 3132.7023604652477}, {"id": "1pMep2AS_MPdobWwDzgkPw", "alias": "4th-avenue-pub-brooklyn", "name": "4th Avenue Pub", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/Gi7PJWArnJwk6wGV99WIhQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/4th-avenue-pub-brooklyn?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 306, "categories": [{"alias": "pubs", "title": "Pubs"}, {"alias": "beergardens", "title": "Beer Gardens"}, {"alias": "beerbar", "title": "Beer Bar"}], "rating": 4.0, "coordinates": {"latitude": 40.682325, "longitude": -73.980126}, "transactions": [], "price": "$$", "location": {"address1": "76 4th Ave", "address2": null, "address3": "", "city": "Brooklyn", "zip_code": "11217", "country": "US", "state": "NY", "display_address": ["76 4th Ave", "Brooklyn, NY 11217"]}, "phone": "+17186432273", "display_phone": "(718) 643-2273", "distance": 2839.66563564612}, {"id": "ZnhRUBos9FGQZrzbcPn6Vg", "alias": "o-haras-restaur ...
# <Response [200]>
# <class 'str'>
# {"businesses": [{"id": "oAjwUCzyvH9gBIOOlf8PtQ", "alias": "the-stinking-rose-pub-and-grindhouse-harcourt", "name": "The Stinking Rose Pub & Grindhouse", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/xsYj7Vzs5j_SHi994_9I7g/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-stinking-rose-pub-and-grindhouse-harcourt?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 1, "categories": [{"alias": "pubs", "title": "Pubs"}], "rating": 5.0, "coordinates": {"latitude": 44.30876, "longitude": -77.80071}, "transactions": [], "price": "$$", "location": {"address1": "26 Bridge West", "address2": "", "address3": "", "city": "Harcourt", "zip_code": "K0L", "country": "CA", "state": "ON", "display_address": ["26 Bridge West", "Harcourt, ON K0L", "Canada"]}, "phone": "+17056530001", "display_phone": "+1 705-653-0001", "distance": 810.2538134017361}, {"id": "OxqUWRZFUOz3r6_4bh4mfg", "alias": "cock-and-bull-new-york", "name": "Cock & Bull", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/-82MfQUN7FXel19Ra9BsLg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/cock-and-bull-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 531, "categories": [{"alias": "british", "title": "British"}, {"alias": "pubs", "title": "Pubs"}, {"alias": "gastropubs", "title": "Gastropubs"}], "rating": 4.0, "coordinates": {"latitude": 40.7560908823673, "longitude": -73.9804858350908}, "transactions": ["restaurant_reservation"], "price": "$$", "location": {"address1": "23 W 45th St", "address2": null, "address3": "", "city": "New York", "zip_code": "10036", "country": "US", "state": "NY", "display_address": ["23 W 45th St", "New York, NY 10036"]}, "phone": "+12128191900", "display_phone": "(212) 819-1900", "distance": 5750.495668005237}, {"id": "3NbhYebjZPjLTWZZyRuhsw", "alias": "the-winslow-new-york-2", "name": "The Winslow", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/KqK_JDisR25T9QQdVvgHNg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-winslow-new-york-2?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 527, "categories": [{"alias": "pubs", "title": "Pubs"}, {"alias": "british", "title": "British"}, {"alias": "cocktailbars", "title": "Cocktail Bars"}], "rating": 4.5, "coordinates": {"latitude": 40.7327766418457, "longitude": -73.9852142333984}, "transactions": ["restaurant_reservation"], "price": "$$", "location": {"address1": "243 E 14th St", "address2": "", "address3": "", "city": "New York", "zip_code": "10003", "country": "US", "state": "NY", "display_address": ["243 E 14th St", "New York, NY 10003"]}, "phone": "+12127777717", "display_phone": "(212) 777-7717", "distance": 3132.7023604652477}, {"id": "1pMep2AS_MPdobWwDzgkPw", "alias": "4th-avenue-pub-brooklyn", "name": "4th Avenue Pub", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/Gi7PJWArnJwk6wGV99WIhQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/4th-avenue-pub-brooklyn?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 306, "categories": [{"alias": "pubs", "title": "Pubs"}, {"alias": "beergardens", "title": "Beer Gardens"}, {"alias": "beerbar", "title": "Beer Bar"}], "rating": 4.0, "coordinates": {"latitude": 40.682325, "longitude": -73.980126}, "transactions": [], "price": "$$", "location": {"address1": "76 4th Ave", "address2": null, "address3": "", "city": "Brooklyn", "zip_code": "11217", "country": "US", "state": "NY", "display_address": ["76 4th Ave", "Brooklyn, NY 11217"]}, "phone": "+17186432273", "display_phone": "(718) 643-2273", "distance": 2839.66563564612}, {"id": "ZnhRUBos9FGQZrzbcPn6Vg", "alias": "o-haras-restaur ...
# <Response [200]>
# <class 'str'>
# {"businesses": [{"id": "oAjwUCzyvH9gBIOOlf8PtQ", "alias": "the-stinking-rose-pub-and-grindhouse-harcourt", "name": "The Stinking Rose Pub & Grindhouse", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/xsYj7Vzs5j_SHi994_9I7g/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-stinking-rose-pub-and-grindhouse-harcourt?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 1, "categories": [{"alias": "pubs", "title": "Pubs"}], "rating": 5.0, "coordinates": {"latitude": 44.30876, "longitude": -77.80071}, "transactions": [], "price": "$$", "location": {"address1": "26 Bridge West", "address2": "", "address3": "", "city": "Harcourt", "zip_code": "K0L", "country": "CA", "state": "ON", "display_address": ["26 Bridge West", "Harcourt, ON K0L", "Canada"]}, "phone": "+17056530001", "display_phone": "+1 705-653-0001", "distance": 810.2538134017361}, {"id": "OxqUWRZFUOz3r6_4bh4mfg", "alias": "cock-and-bull-new-york", "name": "Cock & Bull", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/-82MfQUN7FXel19Ra9BsLg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/cock-and-bull-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 531, "categories": [{"alias": "british", "title": "British"}, {"alias": "pubs", "title": "Pubs"}, {"alias": "gastropubs", "title": "Gastropubs"}], "rating": 4.0, "coordinates": {"latitude": 40.7560908823673, "longitude": -73.9804858350908}, "transactions": ["restaurant_reservation"], "price": "$$", "location": {"address1": "23 W 45th St", "address2": null, "address3": "", "city": "New York", "zip_code": "10036", "country": "US", "state": "NY", "display_address": ["23 W 45th St", "New York, NY 10036"]}, "phone": "+12128191900", "display_phone": "(212) 819-1900", "distance": 5750.495668005237}, {"id": "3NbhYebjZPjLTWZZyRuhsw", "alias": "the-winslow-new-york-2", "name": "The Winslow", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/KqK_JDisR25T9QQdVvgHNg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-winslow-new-york-2?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 527, "categories": [{"alias": "pubs", "title": "Pubs"}, {"alias": "british", "title": "British"}, {"alias": "cocktailbars", "title": "Cocktail Bars"}], "rating": 4.5, "coordinates": {"latitude": 40.7327766418457, "longitude": -73.9852142333984}, "transactions": ["restaurant_reservation"], "price": "$$", "location": {"address1": "243 E 14th St", "address2": "", "address3": "", "city": "New York", "zip_code": "10003", "country": "US", "state": "NY", "display_address": ["243 E 14th St", "New York, NY 10003"]}, "phone": "+12127777717", "display_phone": "(212) 777-7717", "distance": 3132.7023604652477}, {"id": "1pMep2AS_MPdobWwDzgkPw", "alias": "4th-avenue-pub-brooklyn", "name": "4th Avenue Pub", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/Gi7PJWArnJwk6wGV99WIhQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/4th-avenue-pub-brooklyn?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 306, "categories": [{"alias": "pubs", "title": "Pubs"}, {"alias": "beergardens", "title": "Beer Gardens"}, {"alias": "beerbar", "title": "Beer Bar"}], "rating": 4.0, "coordinates": {"latitude": 40.682325, "longitude": -73.980126}, "transactions": [], "price": "$$", "location": {"address1": "76 4th Ave", "address2": null, "address3": "", "city": "Brooklyn", "zip_code": "11217", "country": "US", "state": "NY", "display_address": ["76 4th Ave", "Brooklyn, NY 11217"]}, "phone": "+17186432273", "display_phone": "(718) 643-2273", "distance": 2839.66563564612}, {"id": "ZnhRUBos9FGQZrzbcPn6Vg", "alias": "o-haras-restaur ...
# <Response [200]>
# <class 'str'>
# ...
# <Response [200]>
# <class 'str'>
# {"businesses": [{"id": "oAjwUCzyvH9gBIOOlf8PtQ", "alias": "the-stinking-rose-pub-and-grindhouse-harcourt", "name": "The Stinking Rose Pub & Grindhouse", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/xsYj7Vzs5j_SHi994_9I7g/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-stinking-rose-pub-and-grindhouse-harcourt?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 1, "categories": [{"alias": "pubs", "title": "Pubs"}], "rating": 5.0, "coordinates": {"latitude": 44.30876, "longitude": -77.80071}, "transactions": [], "price": "$$", "location": {"address1": "26 Bridge West", "address2": "", "address3": "", "city": "Harcourt", "zip_code": "K0L", "country": "CA", "state": "ON", "display_address": ["26 Bridge West", "Harcourt, ON K0L", "Canada"]}, "phone": "+17056530001", "display_phone": "+1 705-653-0001", "distance": 810.2538134017361}, {"id": "OxqUWRZFUOz3r6_4bh4mfg", "alias": "cock-and-bull-new-york", "name": "Cock & Bull", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/-82MfQUN7FXel19Ra9BsLg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/cock-and-bull-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 531, "categories": [{"alias": "british", "title": "British"}, {"alias": "pubs", "title": "Pubs"}, {"alias": "gastropubs", "title": "Gastropubs"}], "rating": 4.0, "coordinates": {"latitude": 40.7560908823673, "longitude": -73.9804858350908}, "transactions": ["restaurant_reservation"], "price": "$$", "location": {"address1": "23 W 45th St", "address2": null, "address3": "", "city": "New York", "zip_code": "10036", "country": "US", "state": "NY", "display_address": ["23 W 45th St", "New York, NY 10036"]}, "phone": "+12128191900", "display_phone": "(212) 819-1900", "distance": 5750.495668005237}, {"id": "3NbhYebjZPjLTWZZyRuhsw", "alias": "the-winslow-new-york-2", "name": "The Winslow", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/KqK_JDisR25T9QQdVvgHNg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-winslow-new-york-2?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 527, "categories": [{"alias": "pubs", "title": "Pubs"}, {"alias": "british", "title": "British"}, {"alias": "cocktailbars", "title": "Cocktail Bars"}], "rating": 4.5, "coordinates": {"latitude": 40.7327766418457, "longitude": -73.9852142333984}, "transactions": ["restaurant_reservation"], "price": "$$", "location": {"address1": "243 E 14th St", "address2": "", "address3": "", "city": "New York", "zip_code": "10003", "country": "US", "state": "NY", "display_address": ["243 E 14th St", "New York, NY 10003"]}, "phone": "+12127777717", "display_phone": "(212) 777-7717", "distance": 3132.7023604652477}, {"id": "1pMep2AS_MPdobWwDzgkPw", "alias": "4th-avenue-pub-brooklyn", "name": "4th Avenue Pub", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/Gi7PJWArnJwk6wGV99WIhQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/4th-avenue-pub-brooklyn?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 306, "categories": [{"alias": "pubs", "title": "Pubs"}, {"alias": "beergardens", "title": "Beer Gardens"}, {"alias": "beerbar", "title": "Beer Bar"}], "rating": 4.0, "coordinates": {"latitude": 40.682325, "longitude": -73.980126}, "transactions": [], "price": "$$", "location": {"address1": "76 4th Ave", "address2": null, "address3": "", "city": "Brooklyn", "zip_code": "11217", "country": "US", "state": "NY", "display_address": ["76 4th Ave", "Brooklyn, NY 11217"]}, "phone": "+17186432273", "display_phone": "(718) 643-2273", "distance": 2839.66563564612}, {"id": "ZnhRUBos9FGQZrzbcPn6Vg", "alias": "o-haras-restaur ...
# <Response [200]>
# <class 'str'>
# {"businesses": [{"id": "oAjwUCzyvH9gBIOOlf8PtQ", "alias": "the-stinking-rose-pub-and-grindhouse-harcourt", "name": "The Stinking Rose Pub & Grindhouse", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/xsYj7Vzs5j_SHi994_9I7g/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-stinking-rose-pub-and-grindhouse-harcourt?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 1, "categories": [{"alias": "pubs", "title": "Pubs"}], "rating": 5.0, "coordinates": {"latitude": 44.30876, "longitude": -77.80071}, "transactions": [], "price": "$$", "location": {"address1": "26 Bridge West", "address2": "", "address3": "", "city": "Harcourt", "zip_code": "K0L", "country": "CA", "state": "ON", "display_address": ["26 Bridge West", "Harcourt, ON K0L", "Canada"]}, "phone": "+17056530001", "display_phone": "+1 705-653-0001", "distance": 810.2538134017361}, {"id": "OxqUWRZFUOz3r6_4bh4mfg", "alias": "cock-and-bull-new-york", "name": "Cock & Bull", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/-82MfQUN7FXel19Ra9BsLg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/cock-and-bull-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 531, "categories": [{"alias": "british", "title": "British"}, {"alias": "pubs", "title": "Pubs"}, {"alias": "gastropubs", "title": "Gastropubs"}], "rating": 4.0, "coordinates": {"latitude": 40.7560908823673, "longitude": -73.9804858350908}, "transactions": ["restaurant_reservation"], "price": "$$", "location": {"address1": "23 W 45th St", "address2": null, "address3": "", "city": "New York", "zip_code": "10036", "country": "US", "state": "NY", "display_address": ["23 W 45th St", "New York, NY 10036"]}, "phone": "+12128191900", "display_phone": "(212) 819-1900", "distance": 5750.495668005237}, {"id": "3NbhYebjZPjLTWZZyRuhsw", "alias": "the-winslow-new-york-2", "name": "The Winslow", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/KqK_JDisR25T9QQdVvgHNg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-winslow-new-york-2?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 527, "categories": [{"alias": "pubs", "title": "Pubs"}, {"alias": "british", "title": "British"}, {"alias": "cocktailbars", "title": "Cocktail Bars"}], "rating": 4.5, "coordinates": {"latitude": 40.7327766418457, "longitude": -73.9852142333984}, "transactions": ["restaurant_reservation"], "price": "$$", "location": {"address1": "243 E 14th St", "address2": "", "address3": "", "city": "New York", "zip_code": "10003", "country": "US", "state": "NY", "display_address": ["243 E 14th St", "New York, NY 10003"]}, "phone": "+12127777717", "display_phone": "(212) 777-7717", "distance": 3132.7023604652477}, {"id": "1pMep2AS_MPdobWwDzgkPw", "alias": "4th-avenue-pub-brooklyn", "name": "4th Avenue Pub", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/Gi7PJWArnJwk6wGV99WIhQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/4th-avenue-pub-brooklyn?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 306, "categories": [{"alias": "pubs", "title": "Pubs"}, {"alias": "beergardens", "title": "Beer Gardens"}, {"alias": "beerbar", "title": "Beer Bar"}], "rating": 4.0, "coordinates": {"latitude": 40.682325, "longitude": -73.980126}, "transactions": [], "price": "$$", "location": {"address1": "76 4th Ave", "address2": null, "address3": "", "city": "Brooklyn", "zip_code": "11217", "country": "US", "state": "NY", "display_address": ["76 4th Ave", "Brooklyn, NY 11217"]}, "phone": "+17186432273", "display_phone": "(718) 643-2273", "distance": 2839.66563564612}, {"id": "ZnhRUBos9FGQZrzbcPn6Vg", "alias": "o-haras-restaur ...
# <Response [200]>
# <class 'str'>
# {"businesses": [{"id": "oAjwUCzyvH9gBIOOlf8PtQ", "alias": "the-stinking-rose-pub-and-grindhouse-harcourt", "name": "The Stinking Rose Pub & Grindhouse", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/xsYj7Vzs5j_SHi994_9I7g/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-stinking-rose-pub-and-grindhouse-harcourt?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 1, "categories": [{"alias": "pubs", "title": "Pubs"}], "rating": 5.0, "coordinates": {"latitude": 44.30876, "longitude": -77.80071}, "transactions": [], "price": "$$", "location": {"address1": "26 Bridge West", "address2": "", "address3": "", "city": "Harcourt", "zip_code": "K0L", "country": "CA", "state": "ON", "display_address": ["26 Bridge West", "Harcourt, ON K0L", "Canada"]}, "phone": "+17056530001", "display_phone": "+1 705-653-0001", "distance": 810.2538134017361}, {"id": "OxqUWRZFUOz3r6_4bh4mfg", "alias": "cock-and-bull-new-york", "name": "Cock & Bull", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/-82MfQUN7FXel19Ra9BsLg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/cock-and-bull-new-york?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 531, "categories": [{"alias": "british", "title": "British"}, {"alias": "pubs", "title": "Pubs"}, {"alias": "gastropubs", "title": "Gastropubs"}], "rating": 4.0, "coordinates": {"latitude": 40.7560908823673, "longitude": -73.9804858350908}, "transactions": ["restaurant_reservation"], "price": "$$", "location": {"address1": "23 W 45th St", "address2": null, "address3": "", "city": "New York", "zip_code": "10036", "country": "US", "state": "NY", "display_address": ["23 W 45th St", "New York, NY 10036"]}, "phone": "+12128191900", "display_phone": "(212) 819-1900", "distance": 5750.495668005237}, {"id": "3NbhYebjZPjLTWZZyRuhsw", "alias": "the-winslow-new-york-2", "name": "The Winslow", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/KqK_JDisR25T9QQdVvgHNg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-winslow-new-york-2?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 527, "categories": [{"alias": "pubs", "title": "Pubs"}, {"alias": "british", "title": "British"}, {"alias": "cocktailbars", "title": "Cocktail Bars"}], "rating": 4.5, "coordinates": {"latitude": 40.7327766418457, "longitude": -73.9852142333984}, "transactions": ["restaurant_reservation"], "price": "$$", "location": {"address1": "243 E 14th St", "address2": "", "address3": "", "city": "New York", "zip_code": "10003", "country": "US", "state": "NY", "display_address": ["243 E 14th St", "New York, NY 10003"]}, "phone": "+12127777717", "display_phone": "(212) 777-7717", "distance": 3132.7023604652477}, {"id": "1pMep2AS_MPdobWwDzgkPw", "alias": "4th-avenue-pub-brooklyn", "name": "4th Avenue Pub", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/Gi7PJWArnJwk6wGV99WIhQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/4th-avenue-pub-brooklyn?adjust_creative=DxQeJSiKJUmWIre2XGaKGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=DxQeJSiKJUmWIre2XGaKGg", "review_count": 306, "categories": [{"alias": "pubs", "title": "Pubs"}, {"alias": "beergardens", "title": "Beer Gardens"}, {"alias": "beerbar", "title": "Beer Bar"}], "rating": 4.0, "coordinates": {"latitude": 40.682325, "longitude": -73.980126}, "transactions": [], "price": "$$", "location": {"address1": "76 4th Ave", "address2": null, "address3": "", "city": "Brooklyn", "zip_code": "11217", "country": "US", "state": "NY", "display_address": ["76 4th Ave", "Brooklyn, NY 11217"]}, "phone": "+17186432273", "display_phone": "(718) 643-2273", "distance": 2839.66563564612}, {"id": "ZnhRUBos9FGQZrzbcPn6Vg", "alias": "o-haras-restaur ...

# %% [markdown]
# SQL Questions:
# - What is the average rating of restaurants that have a price label of one dollar sign? Two dollar signs? Three dollar signs?
# - Return the text of the reviews for the most reviewed restaurant.
# - Return the name of the business with the most recent review.
# - Find the highest rated business and return text of the most recent review. If multiple business have the same rating, select the restaurant with the most reviews.
# - Find the lowest rated business and return text of the most recent review. If multiple business have the same rating, select the restaurant with the least reviews.
